# %% [markdown]
# # Caso de estudio: Análisis de sentimiento
#
# En este ejercicio se usará la librería sklearn con el fin de crear un clasificador  que nos permita determinar el sentimiento del texto: positivo o negativo.
#
# El dataset con el que vamos a trabajar podéis descargarlo desde la siguiente URL:
# https://www.kaggle.com/nehasontakke/amazon-unlocked-mobilecsv

# %% [markdown]
# ## Carga del conjunto de datos
# Para resolver este cuaderno de prácticas vamos a trabajar con el dataset *Amazon_Unlocked_Mobile.csv*, liberado por [PromptCloud](https://www.promptcloud.com/) y  que contiene información sobre opiniones, calificaciones y precios a cerca de 400.000 teléfonos móviles libres vendidos en Amazon.com
#
# Para agilizar los cálculos podéis seleccionar una muestra de los datos. (*df = df.sample(frac=0.1, random_state=10)*)

# %%
import pandas as pd
import numpy as np

# Lectura de datos
file_path = './Amazon_Unlocked_Mobile.csv'

df = pd.read_csv(file_path) 

# Selección de la muestra
df = df.sample(frac=0.1, random_state=10)
df.dropna(inplace=True)

#A esto no le tenemos que hacer nada mas, es la carga de datos programada, solo poner el fichero dentro de la carpeta. 
df.head(5)
# Out:
#                                              Product Name Brand Name   Price  \
# 34377       Apple iPhone 5c 8GB (Pink) - Verizon Wireless      Apple  194.99
# 248521  Motorola Droid RAZR MAXX XT912 M Verizon Smart...   Motorola  174.99
# 167661  CNPGD [U.S. Office Extended Warranty] Smartwat...      CNPGD   49.99
# 73287   Apple iPhone 7 Unlocked Phone 256 GB - US Vers...      Apple  922.00
# 277158  Nokia N8 Unlocked GSM Touch Screen Phone Featu...      Nokia   95.00
#
#         Rating                                            Reviews  \
# 34377        1  The phone needed a SIM card, would have been n...
# 248521       5  I was 3 months away from my upgrade and my Str...
# 167661       1                     an experience i want to forget
# 73287        5        GREAT PHONE WORK ACCORDING MY EXPECTATIONS.
# 277158       5  I fell in love with this phone because it did ...
#
#         Review Votes
# 34377            1.0
# 248521           3.0
# 167661           0.0
# 73287            1.0
# 277158           0.0

# %% [markdown]
# ## Pregunta 1
# ### Etiqueta el dataset (1,25 puntos)
#
# Debes crear la variable Sentimiento. Para ello, debemos eliminar los registros de sentimiento neutral que se corresponden a los registros de Rating = 3. Después, se considerará sentimiento positivo (sentiment = 1) a los registros con rating > 3. El resto de registros tendrán un sentimiento negativo (sentiment = 0). *La variable sentiment debe ser numérica*
#
# Muestra por pantalla las dimensiones del dataset.

# %%
df2=df.drop(df[df.Rating == 3].index)

df2.loc[df2['Rating'] < 3, 'Sentimiento'] = 0 
df2.loc[df2['Rating'] > 3, 'Sentimiento'] = 1
#Localizamos los Ratings igual a 3 y los borramos con drop.
#Con loc, asignamos el valor a la columna Sentimiento segun sea mayor o menor a 3.
df2.shape #Tenemos 30737 datos con 7 columnas
# Out:
# (30737, 7)

# %%
df2.head(5) #Se nos crea bien la variable sentimiento.
# Out:
#                                              Product Name Brand Name   Price  \
# 34377       Apple iPhone 5c 8GB (Pink) - Verizon Wireless      Apple  194.99
# 248521  Motorola Droid RAZR MAXX XT912 M Verizon Smart...   Motorola  174.99
# 167661  CNPGD [U.S. Office Extended Warranty] Smartwat...      CNPGD   49.99
# 73287   Apple iPhone 7 Unlocked Phone 256 GB - US Vers...      Apple  922.00
# 277158  Nokia N8 Unlocked GSM Touch Screen Phone Featu...      Nokia   95.00
#
#         Rating                                            Reviews  \
# 34377        1  The phone needed a SIM card, would have been n...
# 248521       5  I was 3 months away from my upgrade and my Str...
# 167661       1                     an experience i want to forget
# 73287        5        GREAT PHONE WORK ACCORDING MY EXPECTATIONS.
# 277158       5  I fell in love with this phone because it did ...
#
#         Review Votes  Sentimiento
# 34377            1.0          0.0
# 248521           3.0          1.0
# 167661           0.0          0.0
# 73287            1.0          1.0
# 277158           0.0          1.0

# %% [markdown]
# ## Pregunta 2
# ### Creación de dataset de entrenamiento y test (1,25 puntos)
#
# Separa el dataset de la pregunta anterior en dos partes (entrenamiento y test) con la proporción 70-30. Muestra el número de filas del dataset de train y el de test.

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df2[['Product Name','Brand Name','Price',
                                                         'Rating','Reviews','Review Votes']],df2['Sentimiento'],test_size=0.3)
#De momento, mantenemos todas las columnas. Ya filtraremos despues la unica que nos interesa, Reviews. 
print(x_train.shape) #Efectivamente, el train es 70% del total y el test 30% del total.
print(x_test.shape)
# Out:
# (21515, 6)
# (9222, 6)

# %%
x_train.head(10)
# Out:
#                                              Product Name     Brand Name  \
# 388248  Sony Ericsson Xperia Play R800i Unlocked Phone...  Sony Ericsson
# 389200  Sony Xperia E C1504 Unlocked Android Phone--U....           Sony
# 293188  Polaroid A5PK 5" Unlocked Smartphone, No Contr...       Polaroid
# 103153  BLU Advance 4.0L Unlocked Smartphone -Global G...            BLU
# 11232     Apple iPhone 4S 16GB (Black) - Locked to Sprint          Apple
# 201182           Huawei Mate 2 - Factory Unlocked (Black)         Huawei
# 2691    ALCATEL OneTouch Idol 3 Global Unlocked 4G LTE...        Alcatel
# 128453  BLU Life Pure Unlocked Phone 32GB ROM, 2GB RAM...            BLU
# 112681  BLU Dash JR 4.0K Android 4.2, 2MP - Unlocked (...            BLU
# 362262  Samsung Galaxy S6 Edge G925i 32GB Unlocked GSM...        Samsung
#
#          Price  Rating                                            Reviews  \
# 388248   83.88       5  aguanta la pela!! buen producto!! tienda respo...
# 389200   34.99       5  This is my first time using android, and i'm l...
# 293188   79.12       2  Such a disappointment. I had high hopes for th...
# 103153  149.99       5                                I recommend it 100%
# 11232    53.00       4  Has worked perfectly but did not totally seem ...
# 201182  229.99       5  For the price this is a great phone! It has al...
# 2691    129.00       5  I can never seem to settle on a phone. I splur...
# 128453  150.00       4                                        Good phone.
# 112681   49.00       4  It was really stressful at first to remove the...
# 362262  519.99       5                                        I loved it.
#
#         Review Votes
# 388248           2.0
# 389200          43.0
# 293188           1.0
# 103153           0.0
# 11232            0.0
# 201182           2.0
# 2691             6.0
# 128453           0.0
# 112681           0.0
# 362262           0.0

# %%
x_test.head(10)
# Out:
#                                              Product Name Brand Name   Price  \
# 293644  Polaroid A6BK 6" Unlocked Smartphone, No Contr...   Polaroid  107.52
# 287678  OtterBox Rugged Defender Series for iPhone 5/5...   OtterBox   39.00
# 44420                Apple iPhone 5s 32GB (Silver) - AT&T      Apple   43.95
# 167082  CNPGD [U.S. Office Extended Warranty] Smartwat...      CNPGD   49.99
# 389284  Sony Xperia E C1504 Unlocked Android Phone--U....       Sony   34.99
# 266996  Nokia Lumia 1020 32GB Unlocked GSM Phone w/ 41...      Nokia  296.00
# 78905   Apple Smart Watch Sport 38mm - Stainless Steel...      Apple  269.99
# 392537  Sony Xperia Z C6602 Unlocked Phone with 5 inch...       Sony  169.99
# 381858  Samsung S5230 Hello Kitty Pink Unlocked GSM Qu...    Samsung   79.00
# 13137   Apple iPhone 4S 16GB Unlocked GSM - White (Cer...      Apple  129.99
#
#         Rating                                            Reviews  \
# 293644       2  It's huge!!! Way too big! Even bigger than the...
# 287678       5  Exactly what I wanted and expected. Terrific p...
# 44420        5                                            Great!!
# 167082       4  Just received the watch so far so good connect...
# 389284       2  I used it for a week. had to return it. Phone ...
# 266996       2  I returned this product. Because flash was not...
# 78905        5  Can't even tell it's refurbished, works like a...
# 392537       5                                          excelente
# 381858       5  This is a really cool phone. My step-daughter ...
# 13137        1        Not factory unlock not working gsm carriers
#
#         Review Votes
# 293644           1.0
# 287678           0.0
# 44420            0.0
# 167082           0.0
# 389284          23.0
# 266996           0.0
# 78905            4.0
# 392537           0.0
# 381858           9.0
# 13137            1.0

# %%
y_train.head(10)
# Out:
# 388248    1.0
# 389200    1.0
# 293188    0.0
# 103153    1.0
# 11232     1.0
# 201182    1.0
# 2691      1.0
# 128453    1.0
# 112681    1.0
# 362262    1.0
# Name: Sentimiento, dtype: float64

# %%
y_test.head(10)
# Out:
# 293644    0.0
# 287678    1.0
# 44420     1.0
# 167082    1.0
# 389284    0.0
# 266996    0.0
# 78905     1.0
# 392537    1.0
# 381858    1.0
# 13137     0.0
# Name: Sentimiento, dtype: float64

# %% [markdown]
# ## Pregunta 3
# ### Entrenamiento del dataset (1,25 puntos)
#
# A continuación debemos utilizar el método de bolsas de palabras y transformar los documentos en una document term matrix.
#
# *Utiliza para ello la función fit() y transform()*

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
#Solo analizamos donde haya emociones, los Review. Creamos la matriz de documentos para train y test.
x_train_matrix = vectorizer.fit_transform(x_train['Reviews']) #Hacemos fit y transform
x_test_matrix = vectorizer.transform(x_test['Reviews']) #SOLO hacemos transform

print(vectorizer.get_feature_names())
# Out:
# ['00', '000',
gig', '2h', '2hours', '2i', '2installed', '2k', '2mbps', '2mm', '2months', '2mp', '2mpinstead', '2nd', '2only', '2pm', '2reasons', '2screen', '2seconds', '2secs', '2sim', '2tb', '2wall', '2way', '2weeks', '2x', '2yrs', '30', '300', '3000', '3000ma', '3000mah', '306', '30fps', '30ft', '30m', '30mbps', '30min', '30mins', '30pm', '30th', '30while', '31', '310', '310mnc', '312', '319', '31ah', '31st', '32', '320', '320g', '320mah', '320x240', '3218b7ca', '322', '3230', '325', '32g', '32gb', '32gbfeatures', '32gbs', '32gig', '32gigs', '33', '330', '3300mah', '33122united', '339', '34', '349', '35', '350', '3500', '3500mah', '354', '355c', '36', '360', '360s', '365', '3650', '37', '370', '37005226', '373', '38', '380', '381', '3845', '385', ...

# %%
x_train_matrix
# Out:
# <21515x18932 sparse matrix of type '<class 'numpy.int64'>'
# 	with 566445 stored elements in Compressed Sparse Row format>

# %%
x_test_matrix
# Out:
# <9222x18932 sparse matrix of type '<class 'numpy.int64'>'
# 	with 246580 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Pregunta 4
# ### Modelos Naive Bayes (1,25 puntos)
#
# Declara y entrena el modelo de Naive Bayes con el conjunto de datos de entrenamiento. Para evaluar el clasificador debes predecir las etiquetas en el conjunto de datos test.
# Como resultado muestra por pantalla los 10 primeros valores de la predicción sobre el conjunto de test.

# %%
from sklearn.naive_bayes import MultinomialNB
clfrNB = MultinomialNB()
clfrNB.fit(x_train_matrix, y_train)
predicted_labels = clfrNB.predict(x_test_matrix.toarray())
#Valores predichos
predicted_labels[0:10]
# Out:
# array([0., 1., 1., 1., 0., 0., 1., 1., 1., 0.])

# %%
#Valores reales
y_test[0:10]
# Out:
# 293644    0.0
# 287678    1.0
# 44420     1.0
# 167082    1.0
# 389284    0.0
# 266996    0.0
# 78905     1.0
# 392537    1.0
# 381858    1.0
# 13137     0.0
# Name: Sentimiento, dtype: float64

# %%
from sklearn.metrics import accuracy_score   #Obtenemos la prediccion concreta 
accuracy_score(y_test,predicted_labels) #Lo hacemos en el Bloque 4, pero ponerlo aqui esta bien para tener un orden de magnitud.
# Out:
# 0.9211667751030145

# %% [markdown]
# ## Pregunta 5
# ### Modelos Regresión logística (1,25 puntos)
#
# Declara y entrena el modelo de Regresicón logística con el conjunto de datos de entrenamiento. Para evaluar el clasificador debes predecir las etiquetas en el conjunto de datos de test.
# Como resultado muestra por pantalla los 10 primeros valores de la predicción sobre el conjunto de test.

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(x_train_matrix, y_train)
predicted_labels2 = classifier.predict(x_test_matrix.toarray())
predicted_labels2[0:10]
# Out:
# C:\Users\inima\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([0., 1., 1., 1., 0., 0., 1., 1., 1., 0.])

# %%
#Valores reales
y_test[0:10]
# Out:
# 293644    0.0
# 287678    1.0
# 44420     1.0
# 167082    1.0
# 389284    0.0
# 266996    0.0
# 78905     1.0
# 392537    1.0
# 381858    1.0
# 13137     0.0
# Name: Sentimiento, dtype: float64

# %%
accuracy_score(y_test,predicted_labels2 )#Lo hacemos en el Bloque 4, pero ponerlo aqui esta bien para tener un orden de magnitud
# Out:
# 0.9360225547603557

# %% [markdown]
# ## Pregunta 6
# ### Modelos SVM (1,25 puntos)
#
# Declara y entrena el modelo SVM con el conjunto de datos de entrenamiento. Para evaluar el clasificador debes predecir las etiquetas en el conjunto de datos de test.
# Como resultado muestra por pantalla los 10 primeros valores de la predicción sobre el conjunto de test.

# %%
from sklearn import svm
clfrSVM = svm.SVC(kernel='linear', C=0.1)
clfrSVM.fit(x_train_matrix, y_train)
predicted_labels3 = clfrSVM.predict(x_test_matrix.toarray())
predicted_labels3[0:10]
# Out:
# array([0., 1., 1., 1., 0., 0., 1., 1., 1., 0.])

# %%
#Valores reales
y_test[0:10]
# Out:
# 293644    0.0
# 287678    1.0
# 44420     1.0
# 167082    1.0
# 389284    0.0
# 266996    0.0
# 78905     1.0
# 392537    1.0
# 381858    1.0
# 13137     0.0
# Name: Sentimiento, dtype: float64

# %%
accuracy_score(y_test,predicted_labels3)#Lo hacemos en el Bloque 4, pero ponerlo aqui esta bien para tener un orden de magnitud.
# Out:
# 0.9322272825851226

# %% [markdown]
# ## Pregunta 7
# ### Ajuste de los parámetros de la entidad countvectorizer (1,25 puntos)
#
# Ajusta la entidad *countvectorizer* a los datos de entrenamiento especificando una frecuencia mínima de documentos de 5 y extrayendo unigramas y bigramas (min_df, ngram_range) y entrena de nuevo el modelo de Naive Bayes.
# Como resultado muestra por pantalla los 10 primeros valores de la predicción sobre el conjunto de test.

# %%
vectorizer2 = CountVectorizer(min_df = 5,ngram_range=(1, 2))
#Solo analizamos donde haya emociones, los Review
x_train_matrix2 = vectorizer2.fit_transform(x_train['Reviews']) #Hacemos fit y transform
x_test_matrix2 = vectorizer2.transform(x_test['Reviews']) #SOLO hacemos transform

print(vectorizer2.get_feature_names())
# Out:
# ['00', '00 and', '00 for', '00 price', '00 the', '00 to', '000', '01', '02', '04', '09', '10', '10 10', '10 15', '10 and', '10 days', '10 for', '10 hours', '10 mins', '10 minutes', '10 months', '10 of', '10 on', '10 phone', '10 seconds', '10 the', '10 times', '10 to', '10 would', '10 year', '10 years', '100', '100 00', '100 and', '100 for', '100 in', '100 ok', '100 phone', '100 recomendado', '100 recommended', '100 satisfaction', '100 satisfied', '100 to', '100 when', '1000', '1020', '1080p', '10th', '11', '110', '11th', '12', '12 hours', '12 year', '120', '125', '128', '128 gb', '128gb', '129', '13', '13 mp', '13 year', '130', '13mp', '13mp camera', '14', '14 days', '14 hours', '140', '1440p', '15', '15 20', '15 and', '15 days', '15 minutes', '15 seconds', '15 years', '150', '1520', '16', '16 and', '16 gb', '16 gig', '16 mp', '160', '16g', '16gb', '16gb microsd', '16gb of', '16gb version', '16mp', '17', '1700', '18', '180', '1800', '19', '190', '1900', '199', '1gb', '1gb of', '1gb ram', '1ghz', '1st', '1st gen', '1st time', '1st week', '20', '20 
predicted_labels4 = clfrNB2.predict(x_test_matrix2.toarray())
#Valores predichos
predicted_labels4[0:10]
# Out:
# array([0., 1., 1., 1., 0., 0., 1., 1., 1., 0.])

# %%
#Valores reales
y_test[0:10]
# Out:
# 293644    0.0
# 287678    1.0
# 44420     1.0
# 167082    1.0
# 389284    0.0
# 266996    0.0
# 78905     1.0
# 392537    1.0
# 381858    1.0
# 13137     0.0
# Name: Sentimiento, dtype: float64

# %%
accuracy_score(y_test,predicted_labels4) #La precision ha aumentado ligeramente.
# Out:
# 0.9342875731945348

# %% [markdown]
# ## Pregunta 8
# ### Ajuste de los parámetros de la entidad tfidfvectorizer (1,25 puntos)
#
# Utiliza en vez de la entidad *countvectorizer* la entidad *tfidfvectorizer* especificando una frecuencia mínima de documentos de 5 y extrayendo también unigramas y bigramas y entrena de nuevo el modelo de Regresión logística. Como resultado muestra por pantalla los 10 primeros valores de la predicción sobre el conjunto de test.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer3 = TfidfVectorizer(min_df = 5,ngram_range=(1, 2))
#Solo analizamos donde haya emociones, los Review
x_train_matrix3 = vectorizer3.fit_transform(x_train['Reviews']) #Hacemos fit y transform
x_test_matrix3 = vectorizer3.transform(x_test['Reviews']) #SOLO hacemos transform

print(vectorizer3.get_feature_names())
# Out:
# ['00', '00 and', '00 for', '00 price', '00 the', '00 to', '000', '01', '02', '04', '09', '10', '10 10', '10 15', '10 and', '10 days', '10 for', '10 hours', '10 mins', '10 minutes', '10 months', '10 of', '10 on', '10 phone', '10 seconds', '10 the', '10 times', '10 to', '10 would', '10 year', '10 years', '100', '100 00', '100 and', '100 for', '100 in', '100 ok', '100 phone', '100 recomendado', '100 recommended', '100 satisfaction', '100 satisfied', '100 to', '100 when', '1000', '1020', '1080p', '10th', '11', '110', '11th', '12', '12 hours', '12 year', '120', '125', '128', '128 gb', '128gb', '129', '13', '13 mp', '13 year', '130', '13mp', '13mp camera', '14', '14 days', '14 hours', '140', '1440p', '15', '15 20', '15 and', '15 days', '15 minutes', '15 seconds', '15 years', '150', '1520', '16', '16 and', '16 gb', '16 gig', '16 mp', '160', '16g', '16gb', '16gb microsd', '16gb of', '16gb version', '16mp', '17', '1700', '18', '180', '1800', '19', '190', '1900', '199', '1gb', '1gb of', '1gb ram', '1ghz', '1st', '1st gen', '1st time', '1st week', '20', '20 days', '20 minutes', '20 of', '20 to', '200', '200 00', '200 bucks', '200 dollars', '2007', '2009', '2010', '2011', '2012', '2013', '2013 and', '2014', '2014 and', '2014 the', '2015', '2015 and', '2015 it', '2016', '2016 and', '2016 it', '2016 the', '21', '2100', '22', '220', '23', '24', '24 hours', '249', '24hrs', '25', '25 and', '250', '26', '27', '28', '29', '299', '2days', '2g', '2g 3g', '2g and', '2gb', '2gb of', '2mp', '2nd', '2nd day', '2nd generation', '2nd one', '30', '30 and', '30 day', '30 days', '30 mins', '30 minutes', '30 seconds', '300', '300 dollars', '300 on', '31', '32', '32 gb', '32 gig', '32g', '32gb', '32gb card', '32gb memory', '32gb of', '32gb sd', '32gig', '34', '349', '35', '350', '36', '360', '3d', '3g', '3g 4g', '3g and', '3g bands', '3g but', '3g hspa', '3g it', '3g network', '3g on', '3g or', '3g phone', '3gb', '3gb of', '3gb ram', '3gs', '3months', '3mp', '3rd', '3rd gen', '3rd one', '3rd party', '3x', '40', '40 and', '400', '400 for', '44', '45', '45 minutes', '450', '46', '48', '48 hours', '49', '4g', '4g and', '4g but', '4g data', '4g in', '4g is', '4g it', '4g lte', '4g network', '4g on', '4g phone', '4g speeds', '4g which', '4g works', '4gb', '4gb internal', '4gb of', '4gb ram', '4glte', '4k', '4k video', '4s', '4s and', '4s in', '4th', '50', '50 bucks', '50 for', '50 it', '50 of', '500', '5000', '512', '512mb', '512mb of', '550', '5c', '5c but', '5c was', '5g', '5gb', '5ghz', '5mm', '5mp', '5mp camera', '5s', '5s and', '5s is', '5s it', '5s to', '5th', '5x', '5x is', '60', '60 days', '600', '600 for', '600 phone', '635', '64', '64 gb', '640', '64gb', '64gb card', '64gb sd', '64gig', '65', '650', '69', '6am', '6gb', '6h', '6p', '6p and', '6s', '6s and', '6s is', '6s plus', '6th', '70', '700', '700 for', '700 phone', '720p', '75', '750', '79', '7th', '80', '800', '810', '82', '820', '822', '84', '850', '850 1900', '8520', '8520 from', '8520 unlocked', '88', '89', '8g', '8gb', '8gb internal', '8gb of', '8mp', '8mp camera', '8x', '90', '90 days', '900', '920', '920 is', '95', '95 of', '9700', '99', '99 and', '99 of', '9900', '9930', 'abandoned', 'abilities', 'ability', 'ability to', 'able', 'able to', 'about', 'about 10', 'about 12', 'about 15', 'about 20', 'about 24', 'about 30', 'about 40', 'about 50', 'about 80', 'about all', 'about an', 'about and', 'about as', 'about battery', 'about but', 'about buying', 'about day', 'about days', 'about different', 'about every', 'about everything', 'about feet', 'about getting', 'about half', 'about hours', 'about how', 'about inches', 'about is', 'about it', 'about its', 'about minutes', 'about month', 'about months', 'about my', 'about not', 'about of', 'about one', 'about or', 'about ordering', 'about other', 'about phone', 'about purchasing', 'about returning', 'about six', 'about that', 'about the', 'about this', 'about three', 'about times', 'about to', 'about two', 'about week', 'about weeks', 'about what ...

# %%
classifier = LogisticRegression()
classifier.fit(x_train_matrix3, y_train)
predicted_labels5 = classifier.predict(x_test_matrix3.toarray())
predicted_labels5[0:10]
# Out:
# array([0., 1., 1., 1., 0., 0., 1., 1., 1., 0.])

# %%
#Valores reales
y_test[0:10]
# Out:
# 293644    0.0
# 287678    1.0
# 44420     1.0
# 167082    1.0
# 389284    0.0
# 266996    0.0
# 78905     1.0
# 392537    1.0
# 381858    1.0
# 13137     0.0
# Name: Sentimiento, dtype: float64

# %%
accuracy_score(y_test,predicted_labels5) #La precision aumenta muy ligeramente
# Out:
# 0.9378659726740404

# %% [markdown]
# Ese seria el fin del ejercicio 3.
