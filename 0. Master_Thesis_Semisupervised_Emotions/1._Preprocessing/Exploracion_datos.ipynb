# %% [markdown]
# Iñigo Martin Melero

# %% [markdown]
# ## Exploracion de datos

# %% [markdown]
# Leemos los datos y los representamos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# ## Parte 1, Datos antes del procesamiento

# %%
df1_ann=pd.read_csv('Bruto/sub_1_annotations.csv')
df1_ann=df1_ann.rename(columns={"jstime": "time"})
df1_phy=pd.read_csv('Bruto/sub_1_physiological.csv')
df1_phy=df1_phy.rename(columns={"daqtime": "time"})
df2_ann=pd.read_csv('Bruto/sub_2_annotations.csv')
df2_ann=df2_ann.rename(columns={"jstime": "time"})
df2_phy=pd.read_csv('Bruto/sub_2_physiological.csv')
df2_phy=df2_phy.rename(columns={"daqtime": "time"})
df3_ann=pd.read_csv('Bruto/sub_3_annotations.csv')
df3_ann=df3_ann.rename(columns={"jstime": "time"})
df3_phy=pd.read_csv('Bruto/sub_3_physiological.csv')
df3_phy=df3_phy.rename(columns={"daqtime": "time"})
df4_ann=pd.read_csv('Bruto/sub_4_annotations.csv')
df4_ann=df4_ann.rename(columns={"jstime": "time"})
df4_phy=pd.read_csv('Bruto/sub_4_physiological.csv')
df4_phy=df4_phy.rename(columns={"daqtime": "time"})
df5_ann=pd.read_csv('Bruto/sub_5_annotations.csv')
df5_ann=df5_ann.rename(columns={"jstime": "time"})
df5_phy=pd.read_csv('Bruto/sub_5_physiological.csv')
df5_phy=df5_phy.rename(columns={"daqtime": "time"})
df6_ann=pd.read_csv('Bruto/sub_6_annotations.csv')
df6_ann=df6_ann.rename(columns={"jstime": "time"})
df6_phy=pd.read_csv('Bruto/sub_6_physiological.csv')
df6_phy=df6_phy.rename(columns={"daqtime": "time"})
df7_ann=pd.read_csv('Bruto/sub_7_annotations.csv')
df7_ann=df7_ann.rename(columns={"jstime": "time"})
df7_phy=pd.read_csv('Bruto/sub_7_physiological.csv')
df7_phy=df7_phy.rename(columns={"daqtime": "time"})
df8_ann=pd.read_csv('Bruto/sub_8_annotations.csv')
df8_ann=df8_ann.rename(columns={"jstime": "time"})
df8_phy=pd.read_csv('Bruto/sub_8_physiological.csv')
df8_phy=df8_phy.rename(columns={"daqtime": "time"})
df9_ann=pd.read_csv('Bruto/sub_9_annotations.csv')
df9_ann=df9_ann.rename(columns={"jstime": "time"})
df9_phy=pd.read_csv('Bruto/sub_9_physiological.csv')
df9_phy=df9_phy.rename(columns={"daqtime": "time"})
df10_ann=pd.read_csv('Bruto/sub_10_annotations.csv')
df10_ann=df10_ann.rename(columns={"jstime": "time"})
df10_phy=pd.read_csv('Bruto/sub_10_physiological.csv')
df10_phy=df10_phy.rename(columns={"daqtime": "time"})
df11_ann=pd.read_csv('Bruto/sub_11_annotations.csv')
df11_ann=df11_ann.rename(columns={"jstime": "time"})
df11_phy=pd.read_csv('Bruto/sub_11_physiological.csv')
df11_phy=df11_phy.rename(columns={"daqtime": "time"})
df12_ann=pd.read_csv('Bruto/sub_12_annotations.csv')
df12_ann=df12_ann.rename(columns={"jstime": "time"})
df12_phy=pd.read_csv('Bruto/sub_12_physiological.csv')
df12_phy=df12_phy.rename(columns={"daqtime": "time"})
df13_ann=pd.read_csv('Bruto/sub_13_annotations.csv')
df13_ann=df13_ann.rename(columns={"jstime": "time"})
df13_phy=pd.read_csv('Bruto/sub_13_physiological.csv')
df13_phy=df13_phy.rename(columns={"daqtime": "time"})
df14_ann=pd.read_csv('Bruto/sub_14_annotations.csv')
df14_ann=df1_ann.rename(columns={"jstime": "time"})
df14_phy=pd.read_csv('Bruto/sub_14_physiological.csv')
df14_phy=df14_phy.rename(columns={"daqtime": "time"})
df15_ann=pd.read_csv('Bruto/sub_15_annotations.csv')
df15_ann=df15_ann.rename(columns={"jstime": "time"})
df15_phy=pd.read_csv('Bruto/sub_15_physiological.csv')
df15_phy=df15_phy.rename(columns={"daqtime": "time"})
df16_ann=pd.read_csv('Bruto/sub_16_annotations.csv')
df16_ann=df16_ann.rename(columns={"jstime": "time"})
df16_phy=pd.read_csv('Bruto/sub_16_physiological.csv')
df16_phy=df16_phy.rename(columns={"daqtime": "time"})
df17_ann=pd.read_csv('Bruto/sub_17_annotations.csv')
df17_ann=df17_ann.rename(columns={"jstime": "time"})
df17_phy=pd.read_csv('Bruto/sub_17_physiological.csv')
df17_phy=df17_phy.rename(columns={"daqtime": "time"})
df18_ann=pd.read_csv('Bruto/sub_18_annotations.csv')
df18_ann=df18_ann.rename(columns={"jstime": "time"})
df18_phy=pd.read_csv('Bruto/sub_18_physiological.csv')
df18_phy=df18_phy.rename(columns={"daqtime": "time"})
df19_ann=pd.read_csv('Bruto/sub_19_annotations.csv')
df19_ann=df19_ann.rename(columns={"jstime": "time"})
df19_phy=pd.read_csv('Bruto/sub_19_physiological.csv')
df19_phy=df19_phy.rename(columns={"daqtime": "time"})
df20_ann=pd.read_csv('Bruto/sub_20_annotations.csv')
df20_ann=df20_ann.rename(columns={"jstime": "time"})
df20_phy=pd.read_csv('Bruto/sub_20_physiological.csv')
df20_phy=df20_phy.rename(columns={"daqtime": "time"})
df21_ann=pd.read_csv('Bruto/sub_21_annotations.csv')
df21_ann=df21_ann.rename(columns={"jstime": "time"})
df21_phy=pd.read_csv('Bruto/sub_21_physiological.csv')
df21_phy=df21_phy.rename(columns={"daqtime": "time"})
df22_ann=pd.read_csv('Bruto/sub_22_annotations.csv')
df22_ann=df22_ann.rename(columns={"jstime": "time"})
df22_phy=pd.read_csv('Bruto/sub_22_physiological.csv')
df22_phy=df22_phy.rename(columns={"daqtime": "time"})
df23_ann=pd.read_csv('Bruto/sub_23_annotations.csv')
df23_ann=df23_ann.rename(columns={"jstime": "time"})
df23_phy=pd.read_csv('Bruto/sub_23_physiological.csv')
df23_phy=df23_phy.rename(columns={"daqtime": "time"})
df24_ann=pd.read_csv('Bruto/sub_24_annotations.csv')
df24_ann=df24_ann.rename(columns={"jstime": "time"})
df24_phy=pd.read_csv('Bruto/sub_24_physiological.csv')
df24_phy=df24_phy.rename(columns={"daqtime": "time"})
df25_ann=pd.read_csv('Bruto/sub_25_annotations.csv')
df25_ann=df25_ann.rename(columns={"jstime": "time"})
df25_phy=pd.read_csv('Bruto/sub_25_physiological.csv')
df25_phy=df25_phy.rename(columns={"daqtime": "time"})
df26_ann=pd.read_csv('Bruto/sub_26_annotations.csv')
df26_ann=df26_ann.rename(columns={"jstime": "time"})
df26_phy=pd.read_csv('Bruto/sub_26_physiological.csv')
df26_phy=df26_phy.rename(columns={"daqtime": "time"})
df27_ann=pd.read_csv('Bruto/sub_27_annotations.csv')
df27_ann=df27_ann.rename(columns={"jstime": "time"})
df27_phy=pd.read_csv('Bruto/sub_27_physiological.csv')
df27_phy=df27_phy.rename(columns={"daqtime": "time"})
df28_ann=pd.read_csv('Bruto/sub_28_annotations.csv')
df28_ann=df28_ann.rename(columns={"jstime": "time"})
df28_phy=pd.read_csv('Bruto/sub_28_physiological.csv')
df28_phy=df28_phy.rename(columns={"daqtime": "time"})
df29_ann=pd.read_csv('Bruto/sub_29_annotations.csv')
df29_ann=df29_ann.rename(columns={"jstime": "time"})
df29_phy=pd.read_csv('Bruto/sub_29_physiological.csv')
df29_phy=df29_phy.rename(columns={"daqtime": "time"})
df30_ann=pd.read_csv('Bruto/sub_30_annotations.csv')
df30_ann=df30_ann.rename(columns={"jstime": "time"})
df30_phy=pd.read_csv('Bruto/sub_30_physiological.csv')
df30_phy=df30_phy.rename(columns={"daqtime": "time"})

# %% [markdown]
# Variable ECG

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="ecg",legend=False,title="Subject 1",color="tab:cyan")
df2_phy.plot(ax=axes[0,1],x="time",y="ecg",legend=False,title="Subject 2",color="tab:cyan")
df3_phy.plot(ax=axes[0,2],x="time",y="ecg",legend=False,title="Subject 3",color="tab:cyan")
df4_phy.plot(ax=axes[0,3],x="time",y="ecg",legend=False,title="Subject 4",color="tab:cyan")
df5_phy.plot(ax=axes[0,4],x="time",y="ecg",legend=False,title="Subject 5",color="tab:cyan")
df6_phy.plot(ax=axes[0,5],x="time",y="ecg",legend=False,title="Subject 6",color="tab:cyan")
df7_phy.plot(ax=axes[1,0],x="time",y="ecg",legend=False,title="Subject 7",color="tab:cyan")
df8_phy.plot(ax=axes[1,1],x="time",y="ecg",legend=False,title="Subject 8",color="tab:cyan")
df9_phy.plot(ax=axes[1,2],x="time",y="ecg",legend=False,title="Subject 9",color="tab:cyan")
df10_phy.plot(ax=axes[1,3],x="time",y="ecg",legend=False,title="Subject 10",color="tab:cyan")
df11_phy.plot(ax=axes[1,4],x="time",y="ecg",legend=False,title="Subject 11",color="tab:cyan")
df12_phy.plot(ax=axes[1,5],x="time",y="ecg",legend=False,title="Subject 12",color="tab:cyan")
df13_phy.plot(ax=axes[2,0],x="time",y="ecg",legend=False,title="Subject 13",color="tab:cyan")
df14_phy.plot(ax=axes[2,1],x="time",y="ecg",legend=False,title="Subject 14",color="tab:cyan")
df15_phy.plot(ax=axes[2,2],x="time",y="ecg",legend=False,title="Subject 15",color="tab:cyan")
df16_phy.plot(ax=axes[2,3],x="time",y="ecg",legend=False,title="Subject 16",color="tab:cyan")
df17_phy.plot(ax=axes[2,4],x="time",y="ecg",legend=False,title="Subject 17",color="tab:cyan")
df18_phy.plot(ax=axes[2,5],x="time",y="ecg",legend=False,title="Subject 18",color="tab:cyan")
df19_phy.plot(ax=axes[3,0],x="time",y="ecg",legend=False,title="Subject 19",color="tab:cyan")
df20_phy.plot(ax=axes[3,1],x="time",y="ecg",legend=False,title="Subject 20",color="tab:cyan")
df21_phy.plot(ax=axes[3,2],x="time",y="ecg",legend=False,title="Subject 21",color="tab:cyan")
df22_phy.plot(ax=axes[3,3],x="time",y="ecg",legend=False,title="Subject 22",color="tab:cyan")
df23_phy.plot(ax=axes[3,4],x="time",y="ecg",legend=False,title="Subject 23",color="tab:cyan")
df24_phy.plot(ax=axes[3,5],x="time",y="ecg",legend=False,title="Subject 24",color="tab:cyan")
df25_phy.plot(ax=axes[4,0],x="time",y="ecg",legend=False,title="Subject 25",color="tab:cyan")
df26_phy.plot(ax=axes[4,1],x="time",y="ecg",legend=False,title="Subject 26",color="tab:cyan")
df27_phy.plot(ax=axes[4,2],x="time",y="ecg",legend=False,title="Subject 27",color="tab:cyan")
df28_phy.plot(ax=axes[4,3],x="time",y="ecg",legend=False,title="Subject 28",color="tab:cyan")
df29_phy.plot(ax=axes[4,4],x="time",y="ecg",legend=False,title="Subject 29",color="tab:cyan")
df30_phy.plot(ax=axes[4,5],x="time",y="ecg",legend=False,title="Subject 30",color="tab:cyan")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="ecg",legend=False,title="Subject 1",color="tab:cyan")
df2_phy.plot(ax=axes[0,1],x="time",y="ecg",legend=False,title="Subject 2",color="tab:cyan")
df3_phy.plot(ax=axes[0,2],x="time",y="ecg",legend=False,title="Subject 3",color="tab:cyan")
df4_phy.plot(ax=axes[0,3],x="time",y="ecg",legend=False,title="Subject 4",color="tab:cyan")
df5_phy.plot(ax=axes[0,4],x="time",y="ecg",legend=False,title="Subject 5",color="tab:cyan")
df6_phy.plot(ax=axes[0,5],x="time",y="ecg",legend=False,title="Subject 6",color="tab:cyan")
df7_phy.plot(ax=axes[1,0],x="time",y="ecg",legend=False,title="Subject 7",color="tab:cyan")
df8_phy.plot(ax=axes[1,1],x="time",y="ecg",legend=False,title="Subject 8",color="tab:cyan")
df9_phy.plot(ax=axes[1,2],x="time",y="ecg",legend=False,title="Subject 9",color="tab:cyan")
df10_phy.plot(ax=axes[1,3],x="time",y="ecg",legend=False,title="Subject 10",color="tab:cyan")
df11_phy.plot(ax=axes[1,4],x="time",y="ecg",legend=False,title="Subject 11",color="tab:cyan")
df12_phy.plot(ax=axes[1,5],x="time",y="ecg",legend=False,title="Subject 12",color="tab:cyan")
df13_phy.plot(ax=axes[2,0],x="time",y="ecg",legend=False,title="Subject 13",color="tab:cyan")
df14_phy.plot(ax=axes[2,1],x="time",y="ecg",legend=False,title="Subject 14",color="tab:cyan")
df15_phy.plot(ax=axes[2,2],x="time",y="ecg",legend=False,title="Subject 15",color="tab:cyan")
df16_phy.plot(ax=axes[2,3],x="time",y="ecg",legend=False,title="Subject 16",color="tab:cyan")
df17_phy.plot(ax=axes[2,4],x="time",y="ecg",legend=False,title="Subject 17",color="tab:cyan")
df18_phy.plot(ax=axes[2,5],x="time",y="ecg",legend=False,title="Subject 18",color="tab:cyan")
df19_phy.plot(ax=axes[3,0],x="time",y="ecg",legend=False,title="Subject 19",color="tab:cyan")
df20_phy.plot(ax=axes[3,1],x="time",y="ecg",legend=False,title="Subject 20",color="tab:cyan")
df21_phy.plot(ax=axes[3,2],x="time",y="ecg",legend=False,title="Subject 21",color="tab:cyan")
df22_phy.plot(ax=axes[3,3],x="time",y="ecg",legend=False,title="Subject 22",color="tab:cyan")
df23_phy.plot(ax=axes[3,4],x="time",y="ecg",legend=False,title="Subject 23",color="tab:cyan")
df24_phy.plot(ax=axes[3,5],x="time",y="ecg",legend=False,title="Subject 24",color="tab:cyan")
df25_phy.plot(ax=axes[4,0],x="time",y="ecg",legend=False,title="Subject 25",color="tab:cyan")
df26_phy.plot(ax=axes[4,1],x="time",y="ecg",legend=False,title="Subject 26",color="tab:cyan")
df27_phy.plot(ax=axes[4,2],x="time",y="ecg",legend=False,title="Subject 27",color="tab:cyan")
df28_phy.plot(ax=axes[4,3],x="time",y="ecg",legend=False,title="Subject 28",color="tab:cyan")
df29_phy.plot(ax=axes[4,4],x="time",y="ecg",legend=False,title="Subject 29",color="tab:cyan")
df30_phy.plot(ax=axes[4,5],x="time",y="ecg",legend=False,title="Subject 30",color="tab:cyan")
plt.setp(axes, xlim=(0,2000))
fig.tight_layout()

# %% [markdown]
# Variable BVP

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="bvp",legend=False,title="Subject 1",color="tab:olive")
df2_phy.plot(ax=axes[0,1],x="time",y="bvp",legend=False,title="Subject 2",color="tab:olive")
df3_phy.plot(ax=axes[0,2],x="time",y="bvp",legend=False,title="Subject 3",color="tab:olive")
df4_phy.plot(ax=axes[0,3],x="time",y="bvp",legend=False,title="Subject 4",color="tab:olive")
df5_phy.plot(ax=axes[0,4],x="time",y="bvp",legend=False,title="Subject 5",color="tab:olive")
df6_phy.plot(ax=axes[0,5],x="time",y="bvp",legend=False,title="Subject 6",color="tab:olive")
df7_phy.plot(ax=axes[1,0],x="time",y="bvp",legend=False,title="Subject 7",color="tab:olive")
df8_phy.plot(ax=axes[1,1],x="time",y="bvp",legend=False,title="Subject 8",color="tab:olive")
df9_phy.plot(ax=axes[1,2],x="time",y="bvp",legend=False,title="Subject 9",color="tab:olive")
df10_phy.plot(ax=axes[1,3],x="time",y="bvp",legend=False,title="Subject 10",color="tab:olive")
df11_phy.plot(ax=axes[1,4],x="time",y="bvp",legend=False,title="Subject 11",color="tab:olive")
df12_phy.plot(ax=axes[1,5],x="time",y="bvp",legend=False,title="Subject 12",color="tab:olive")
df13_phy.plot(ax=axes[2,0],x="time",y="bvp",legend=False,title="Subject 13",color="tab:olive")
df14_phy.plot(ax=axes[2,1],x="time",y="bvp",legend=False,title="Subject 14",color="tab:olive")
df15_phy.plot(ax=axes[2,2],x="time",y="bvp",legend=False,title="Subject 15",color="tab:olive")
df16_phy.plot(ax=axes[2,3],x="time",y="bvp",legend=False,title="Subject 16",color="tab:olive")
df17_phy.plot(ax=axes[2,4],x="time",y="bvp",legend=False,title="Subject 17",color="tab:olive")
df18_phy.plot(ax=axes[2,5],x="time",y="bvp",legend=False,title="Subject 18",color="tab:olive")
df19_phy.plot(ax=axes[3,0],x="time",y="bvp",legend=False,title="Subject 19",color="tab:olive")
df20_phy.plot(ax=axes[3,1],x="time",y="bvp",legend=False,title="Subject 20",color="tab:olive")
df21_phy.plot(ax=axes[3,2],x="time",y="bvp",legend=False,title="Subject 21",color="tab:olive")
df22_phy.plot(ax=axes[3,3],x="time",y="bvp",legend=False,title="Subject 22",color="tab:olive")
df23_phy.plot(ax=axes[3,4],x="time",y="bvp",legend=False,title="Subject 23",color="tab:olive")
df24_phy.plot(ax=axes[3,5],x="time",y="bvp",legend=False,title="Subject 24",color="tab:olive")
df25_phy.plot(ax=axes[4,0],x="time",y="bvp",legend=False,title="Subject 25",color="tab:olive")
df26_phy.plot(ax=axes[4,1],x="time",y="bvp",legend=False,title="Subject 26",color="tab:olive")
df27_phy.plot(ax=axes[4,2],x="time",y="bvp",legend=False,title="Subject 27",color="tab:olive")
df28_phy.plot(ax=axes[4,3],x="time",y="bvp",legend=False,title="Subject 28",color="tab:olive")
df29_phy.plot(ax=axes[4,4],x="time",y="bvp",legend=False,title="Subject 29",color="tab:olive")
df30_phy.plot(ax=axes[4,5],x="time",y="bvp",legend=False,title="Subject 30",color="tab:olive")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="bvp",legend=False,title="Subject 1",color="tab:olive")
df2_phy.plot(ax=axes[0,1],x="time",y="bvp",legend=False,title="Subject 2",color="tab:olive")
df3_phy.plot(ax=axes[0,2],x="time",y="bvp",legend=False,title="Subject 3",color="tab:olive")
df4_phy.plot(ax=axes[0,3],x="time",y="bvp",legend=False,title="Subject 4",color="tab:olive")
df5_phy.plot(ax=axes[0,4],x="time",y="bvp",legend=False,title="Subject 5",color="tab:olive")
df6_phy.plot(ax=axes[0,5],x="time",y="bvp",legend=False,title="Subject 6",color="tab:olive")
df7_phy.plot(ax=axes[1,0],x="time",y="bvp",legend=False,title="Subject 7",color="tab:olive")
df8_phy.plot(ax=axes[1,1],x="time",y="bvp",legend=False,title="Subject 8",color="tab:olive")
df9_phy.plot(ax=axes[1,2],x="time",y="bvp",legend=False,title="Subject 9",color="tab:olive")
df10_phy.plot(ax=axes[1,3],x="time",y="bvp",legend=False,title="Subject 10",color="tab:olive")
df11_phy.plot(ax=axes[1,4],x="time",y="bvp",legend=False,title="Subject 11",color="tab:olive")
df12_phy.plot(ax=axes[1,5],x="time",y="bvp",legend=False,title="Subject 12",color="tab:olive")
df13_phy.plot(ax=axes[2,0],x="time",y="bvp",legend=False,title="Subject 13",color="tab:olive")
df14_phy.plot(ax=axes[2,1],x="time",y="bvp",legend=False,title="Subject 14",color="tab:olive")
df15_phy.plot(ax=axes[2,2],x="time",y="bvp",legend=False,title="Subject 15",color="tab:olive")
df16_phy.plot(ax=axes[2,3],x="time",y="bvp",legend=False,title="Subject 16",color="tab:olive")
df17_phy.plot(ax=axes[2,4],x="time",y="bvp",legend=False,title="Subject 17",color="tab:olive")
df18_phy.plot(ax=axes[2,5],x="time",y="bvp",legend=False,title="Subject 18",color="tab:olive")
df19_phy.plot(ax=axes[3,0],x="time",y="bvp",legend=False,title="Subject 19",color="tab:olive")
df20_phy.plot(ax=axes[3,1],x="time",y="bvp",legend=False,title="Subject 20",color="tab:olive")
df21_phy.plot(ax=axes[3,2],x="time",y="bvp",legend=False,title="Subject 21",color="tab:olive")
df22_phy.plot(ax=axes[3,3],x="time",y="bvp",legend=False,title="Subject 22",color="tab:olive")
df23_phy.plot(ax=axes[3,4],x="time",y="bvp",legend=False,title="Subject 23",color="tab:olive")
df24_phy.plot(ax=axes[3,5],x="time",y="bvp",legend=False,title="Subject 24",color="tab:olive")
df25_phy.plot(ax=axes[4,0],x="time",y="bvp",legend=False,title="Subject 25",color="tab:olive")
df26_phy.plot(ax=axes[4,1],x="time",y="bvp",legend=False,title="Subject 26",color="tab:olive")
df27_phy.plot(ax=axes[4,2],x="time",y="bvp",legend=False,title="Subject 27",color="tab:olive")
df28_phy.plot(ax=axes[4,3],x="time",y="bvp",legend=False,title="Subject 28",color="tab:olive")
df29_phy.plot(ax=axes[4,4],x="time",y="bvp",legend=False,title="Subject 29",color="tab:olive")
df30_phy.plot(ax=axes[4,5],x="time",y="bvp",legend=False,title="Subject 30",color="tab:olive")
plt.setp(axes, xlim=(0,2000))
fig.tight_layout()

# %% [markdown]
# Variable GSR

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="gsr",legend=False,title="Subject 1",color="tab:green")
df2_phy.plot(ax=axes[0,1],x="time",y="gsr",legend=False,title="Subject 2",color="tab:green")
df3_phy.plot(ax=axes[0,2],x="time",y="gsr",legend=False,title="Subject 3",color="tab:green")
df4_phy.plot(ax=axes[0,3],x="time",y="gsr",legend=False,title="Subject 4",color="tab:green")
df5_phy.plot(ax=axes[0,4],x="time",y="gsr",legend=False,title="Subject 5",color="tab:green")
df6_phy.plot(ax=axes[0,5],x="time",y="gsr",legend=False,title="Subject 6",color="tab:green")
df7_phy.plot(ax=axes[1,0],x="time",y="gsr",legend=False,title="Subject 7",color="tab:green")
df8_phy.plot(ax=axes[1,1],x="time",y="gsr",legend=False,title="Subject 8",color="tab:green")
df9_phy.plot(ax=axes[1,2],x="time",y="gsr",legend=False,title="Subject 9",color="tab:green")
df10_phy.plot(ax=axes[1,3],x="time",y="gsr",legend=False,title="Subject 10",color="tab:green")
df11_phy.plot(ax=axes[1,4],x="time",y="gsr",legend=False,title="Subject 11",color="tab:green")
df12_phy.plot(ax=axes[1,5],x="time",y="gsr",legend=False,title="Subject 12",color="tab:green")
df13_phy.plot(ax=axes[2,0],x="time",y="gsr",legend=False,title="Subject 13",color="tab:green")
df14_phy.plot(ax=axes[2,1],x="time",y="gsr",legend=False,title="Subject 14",color="tab:green")
df15_phy.plot(ax=axes[2,2],x="time",y="gsr",legend=False,title="Subject 15",color="tab:green")
df16_phy.plot(ax=axes[2,3],x="time",y="gsr",legend=False,title="Subject 16",color="tab:green")
df17_phy.plot(ax=axes[2,4],x="time",y="gsr",legend=False,title="Subject 17",color="tab:green")
df18_phy.plot(ax=axes[2,5],x="time",y="gsr",legend=False,title="Subject 18",color="tab:green")
df19_phy.plot(ax=axes[3,0],x="time",y="gsr",legend=False,title="Subject 19",color="tab:green")
df20_phy.plot(ax=axes[3,1],x="time",y="gsr",legend=False,title="Subject 20",color="tab:green")
df21_phy.plot(ax=axes[3,2],x="time",y="gsr",legend=False,title="Subject 21",color="tab:green")
df22_phy.plot(ax=axes[3,3],x="time",y="gsr",legend=False,title="Subject 22",color="tab:green")
df23_phy.plot(ax=axes[3,4],x="time",y="gsr",legend=False,title="Subject 23",color="tab:green")
df24_phy.plot(ax=axes[3,5],x="time",y="gsr",legend=False,title="Subject 24",color="tab:green")
df25_phy.plot(ax=axes[4,0],x="time",y="gsr",legend=False,title="Subject 25",color="tab:green")
df26_phy.plot(ax=axes[4,1],x="time",y="gsr",legend=False,title="Subject 26",color="tab:green")
df27_phy.plot(ax=axes[4,2],x="time",y="gsr",legend=False,title="Subject 27",color="tab:green")
df28_phy.plot(ax=axes[4,3],x="time",y="gsr",legend=False,title="Subject 28",color="tab:green")
df29_phy.plot(ax=axes[4,4],x="time",y="gsr",legend=False,title="Subject 29",color="tab:green")
df30_phy.plot(ax=axes[4,5],x="time",y="gsr",legend=False,title="Subject 30",color="tab:green")
fig.tight_layout()

# %% [markdown]
# Variable RSP

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="rsp",legend=False,title="Subject 1",color="tab:red")
df2_phy.plot(ax=axes[0,1],x="time",y="rsp",legend=False,title="Subject 2",color="tab:red")
df3_phy.plot(ax=axes[0,2],x="time",y="rsp",legend=False,title="Subject 3",color="tab:red")
df4_phy.plot(ax=axes[0,3],x="time",y="rsp",legend=False,title="Subject 4",color="tab:red")
df5_phy.plot(ax=axes[0,4],x="time",y="rsp",legend=False,title="Subject 5",color="tab:red")
df6_phy.plot(ax=axes[0,5],x="time",y="rsp",legend=False,title="Subject 6",color="tab:red")
df7_phy.plot(ax=axes[1,0],x="time",y="rsp",legend=False,title="Subject 7",color="tab:red")
df8_phy.plot(ax=axes[1,1],x="time",y="rsp",legend=False,title="Subject 8",color="tab:red")
df9_phy.plot(ax=axes[1,2],x="time",y="rsp",legend=False,title="Subject 9",color="tab:red")
df10_phy.plot(ax=axes[1,3],x="time",y="rsp",legend=False,title="Subject 10",color="tab:red")
df11_phy.plot(ax=axes[1,4],x="time",y="rsp",legend=False,title="Subject 11",color="tab:red")
df12_phy.plot(ax=axes[1,5],x="time",y="rsp",legend=False,title="Subject 12",color="tab:red")
df13_phy.plot(ax=axes[2,0],x="time",y="rsp",legend=False,title="Subject 13",color="tab:red")
df14_phy.plot(ax=axes[2,1],x="time",y="rsp",legend=False,title="Subject 14",color="tab:red")
df15_phy.plot(ax=axes[2,2],x="time",y="rsp",legend=False,title="Subject 15",color="tab:red")
df16_phy.plot(ax=axes[2,3],x="time",y="rsp",legend=False,title="Subject 16",color="tab:red")
df17_phy.plot(ax=axes[2,4],x="time",y="rsp",legend=False,title="Subject 17",color="tab:red")
df18_phy.plot(ax=axes[2,5],x="time",y="rsp",legend=False,title="Subject 18",color="tab:red")
df19_phy.plot(ax=axes[3,0],x="time",y="rsp",legend=False,title="Subject 19",color="tab:red")
df20_phy.plot(ax=axes[3,1],x="time",y="rsp",legend=False,title="Subject 20",color="tab:red")
df21_phy.plot(ax=axes[3,2],x="time",y="rsp",legend=False,title="Subject 21",color="tab:red")
df22_phy.plot(ax=axes[3,3],x="time",y="rsp",legend=False,title="Subject 22",color="tab:red")
df23_phy.plot(ax=axes[3,4],x="time",y="rsp",legend=False,title="Subject 23",color="tab:red")
df24_phy.plot(ax=axes[3,5],x="time",y="rsp",legend=False,title="Subject 24",color="tab:red")
df25_phy.plot(ax=axes[4,0],x="time",y="rsp",legend=False,title="Subject 25",color="tab:red")
df26_phy.plot(ax=axes[4,1],x="time",y="rsp",legend=False,title="Subject 26",color="tab:red")
df27_phy.plot(ax=axes[4,2],x="time",y="rsp",legend=False,title="Subject 27",color="tab:red")
df28_phy.plot(ax=axes[4,3],x="time",y="rsp",legend=False,title="Subject 28",color="tab:red")
df29_phy.plot(ax=axes[4,4],x="time",y="rsp",legend=False,title="Subject 29",color="tab:red")
df30_phy.plot(ax=axes[4,5],x="time",y="rsp",legend=False,title="Subject 30",color="tab:red")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="rsp",legend=False,title="Subject 1",color="tab:red")
df2_phy.plot(ax=axes[0,1],x="time",y="rsp",legend=False,title="Subject 2",color="tab:red")
df3_phy.plot(ax=axes[0,2],x="time",y="rsp",legend=False,title="Subject 3",color="tab:red")
df4_phy.plot(ax=axes[0,3],x="time",y="rsp",legend=False,title="Subject 4",color="tab:red")
df5_phy.plot(ax=axes[0,4],x="time",y="rsp",legend=False,title="Subject 5",color="tab:red")
df6_phy.plot(ax=axes[0,5],x="time",y="rsp",legend=False,title="Subject 6",color="tab:red")
df7_phy.plot(ax=axes[1,0],x="time",y="rsp",legend=False,title="Subject 7",color="tab:red")
df8_phy.plot(ax=axes[1,1],x="time",y="rsp",legend=False,title="Subject 8",color="tab:red")
df9_phy.plot(ax=axes[1,2],x="time",y="rsp",legend=False,title="Subject 9",color="tab:red")
df10_phy.plot(ax=axes[1,3],x="time",y="rsp",legend=False,title="Subject 10",color="tab:red")
df11_phy.plot(ax=axes[1,4],x="time",y="rsp",legend=False,title="Subject 11",color="tab:red")
df12_phy.plot(ax=axes[1,5],x="time",y="rsp",legend=False,title="Subject 12",color="tab:red")
df13_phy.plot(ax=axes[2,0],x="time",y="rsp",legend=False,title="Subject 13",color="tab:red")
df14_phy.plot(ax=axes[2,1],x="time",y="rsp",legend=False,title="Subject 14",color="tab:red")
df15_phy.plot(ax=axes[2,2],x="time",y="rsp",legend=False,title="Subject 15",color="tab:red")
df16_phy.plot(ax=axes[2,3],x="time",y="rsp",legend=False,title="Subject 16",color="tab:red")
df17_phy.plot(ax=axes[2,4],x="time",y="rsp",legend=False,title="Subject 17",color="tab:red")
df18_phy.plot(ax=axes[2,5],x="time",y="rsp",legend=False,title="Subject 18",color="tab:red")
df19_phy.plot(ax=axes[3,0],x="time",y="rsp",legend=False,title="Subject 19",color="tab:red")
df20_phy.plot(ax=axes[3,1],x="time",y="rsp",legend=False,title="Subject 20",color="tab:red")
df21_phy.plot(ax=axes[3,2],x="time",y="rsp",legend=False,title="Subject 21",color="tab:red")
df22_phy.plot(ax=axes[3,3],x="time",y="rsp",legend=False,title="Subject 22",color="tab:red")
df23_phy.plot(ax=axes[3,4],x="time",y="rsp",legend=False,title="Subject 23",color="tab:red")
df24_phy.plot(ax=axes[3,5],x="time",y="rsp",legend=False,title="Subject 24",color="tab:red")
df25_phy.plot(ax=axes[4,0],x="time",y="rsp",legend=False,title="Subject 25",color="tab:red")
df26_phy.plot(ax=axes[4,1],x="time",y="rsp",legend=False,title="Subject 26",color="tab:red")
df27_phy.plot(ax=axes[4,2],x="time",y="rsp",legend=False,title="Subject 27",color="tab:red")
df28_phy.plot(ax=axes[4,3],x="time",y="rsp",legend=False,title="Subject 28",color="tab:red")
df29_phy.plot(ax=axes[4,4],x="time",y="rsp",legend=False,title="Subject 29",color="tab:red")
df30_phy.plot(ax=axes[4,5],x="time",y="rsp",legend=False,title="Subject 30",color="tab:red")
plt.setp(axes, xlim=(0,10000))
fig.tight_layout()

# %% [markdown]
# Variable skt

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="skt",legend=False,title="Subject 1",color="tab:purple")
df2_phy.plot(ax=axes[0,1],x="time",y="skt",legend=False,title="Subject 2",color="tab:purple")
df3_phy.plot(ax=axes[0,2],x="time",y="skt",legend=False,title="Subject 3",color="tab:purple")
df4_phy.plot(ax=axes[0,3],x="time",y="skt",legend=False,title="Subject 4",color="tab:purple")
df5_phy.plot(ax=axes[0,4],x="time",y="skt",legend=False,title="Subject 5",color="tab:purple")
df6_phy.plot(ax=axes[0,5],x="time",y="skt",legend=False,title="Subject 6",color="tab:purple")
df7_phy.plot(ax=axes[1,0],x="time",y="skt",legend=False,title="Subject 7",color="tab:purple")
df8_phy.plot(ax=axes[1,1],x="time",y="skt",legend=False,title="Subject 8",color="tab:purple")
df9_phy.plot(ax=axes[1,2],x="time",y="skt",legend=False,title="Subject 9",color="tab:purple")
df10_phy.plot(ax=axes[1,3],x="time",y="skt",legend=False,title="Subject 10",color="tab:purple")
df11_phy.plot(ax=axes[1,4],x="time",y="skt",legend=False,title="Subject 11",color="tab:purple")
df12_phy.plot(ax=axes[1,5],x="time",y="skt",legend=False,title="Subject 12",color="tab:purple")
df13_phy.plot(ax=axes[2,0],x="time",y="skt",legend=False,title="Subject 13",color="tab:purple")
df14_phy.plot(ax=axes[2,1],x="time",y="skt",legend=False,title="Subject 14",color="tab:purple")
df15_phy.plot(ax=axes[2,2],x="time",y="skt",legend=False,title="Subject 15",color="tab:purple")
df16_phy.plot(ax=axes[2,3],x="time",y="skt",legend=False,title="Subject 16",color="tab:purple")
df17_phy.plot(ax=axes[2,4],x="time",y="skt",legend=False,title="Subject 17",color="tab:purple")
df18_phy.plot(ax=axes[2,5],x="time",y="skt",legend=False,title="Subject 18",color="tab:purple")
df19_phy.plot(ax=axes[3,0],x="time",y="skt",legend=False,title="Subject 19",color="tab:purple")
df20_phy.plot(ax=axes[3,1],x="time",y="skt",legend=False,title="Subject 20",color="tab:purple")
df21_phy.plot(ax=axes[3,2],x="time",y="skt",legend=False,title="Subject 21",color="tab:purple")
df22_phy.plot(ax=axes[3,3],x="time",y="skt",legend=False,title="Subject 22",color="tab:purple")
df23_phy.plot(ax=axes[3,4],x="time",y="skt",legend=False,title="Subject 23",color="tab:purple")
df24_phy.plot(ax=axes[3,5],x="time",y="skt",legend=False,title="Subject 24",color="tab:purple")
df25_phy.plot(ax=axes[4,0],x="time",y="skt",legend=False,title="Subject 25",color="tab:purple")
df26_phy.plot(ax=axes[4,1],x="time",y="skt",legend=False,title="Subject 26",color="tab:purple")
df27_phy.plot(ax=axes[4,2],x="time",y="skt",legend=False,title="Subject 27",color="tab:purple")
df28_phy.plot(ax=axes[4,3],x="time",y="skt",legend=False,title="Subject 28",color="tab:purple")
df29_phy.plot(ax=axes[4,4],x="time",y="skt",legend=False,title="Subject 29",color="tab:purple")
df30_phy.plot(ax=axes[4,5],x="time",y="skt",legend=False,title="Subject 30",color="tab:purple")
fig.tight_layout()

# %% [markdown]
# Variable emg_zygo

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="emg_zygo",legend=False,title="Subject 1",color="tab:brown")
df2_phy.plot(ax=axes[0,1],x="time",y="emg_zygo",legend=False,title="Subject 2",color="tab:brown")
df3_phy.plot(ax=axes[0,2],x="time",y="emg_zygo",legend=False,title="Subject 3",color="tab:brown")
df4_phy.plot(ax=axes[0,3],x="time",y="emg_zygo",legend=False,title="Subject 4",color="tab:brown")
df5_phy.plot(ax=axes[0,4],x="time",y="emg_zygo",legend=False,title="Subject 5",color="tab:brown")
df6_phy.plot(ax=axes[0,5],x="time",y="emg_zygo",legend=False,title="Subject 6",color="tab:brown")
df7_phy.plot(ax=axes[1,0],x="time",y="emg_zygo",legend=False,title="Subject 7",color="tab:brown")
df8_phy.plot(ax=axes[1,1],x="time",y="emg_zygo",legend=False,title="Subject 8",color="tab:brown")
df9_phy.plot(ax=axes[1,2],x="time",y="emg_zygo",legend=False,title="Subject 9",color="tab:brown")
df10_phy.plot(ax=axes[1,3],x="time",y="emg_zygo",legend=False,title="Subject 10",color="tab:brown")
df11_phy.plot(ax=axes[1,4],x="time",y="emg_zygo",legend=False,title="Subject 11",color="tab:brown")
df12_phy.plot(ax=axes[1,5],x="time",y="emg_zygo",legend=False,title="Subject 12",color="tab:brown")
df13_phy.plot(ax=axes[2,0],x="time",y="emg_zygo",legend=False,title="Subject 13",color="tab:brown")
df14_phy.plot(ax=axes[2,1],x="time",y="emg_zygo",legend=False,title="Subject 14",color="tab:brown")
df15_phy.plot(ax=axes[2,2],x="time",y="emg_zygo",legend=False,title="Subject 15",color="tab:brown")
df16_phy.plot(ax=axes[2,3],x="time",y="emg_zygo",legend=False,title="Subject 16",color="tab:brown")
df17_phy.plot(ax=axes[2,4],x="time",y="emg_zygo",legend=False,title="Subject 17",color="tab:brown")
df18_phy.plot(ax=axes[2,5],x="time",y="emg_zygo",legend=False,title="Subject 18",color="tab:brown")
df19_phy.plot(ax=axes[3,0],x="time",y="emg_zygo",legend=False,title="Subject 19",color="tab:brown")
df20_phy.plot(ax=axes[3,1],x="time",y="emg_zygo",legend=False,title="Subject 20",color="tab:brown")
df21_phy.plot(ax=axes[3,2],x="time",y="emg_zygo",legend=False,title="Subject 21",color="tab:brown")
df22_phy.plot(ax=axes[3,3],x="time",y="emg_zygo",legend=False,title="Subject 22",color="tab:brown")
df23_phy.plot(ax=axes[3,4],x="time",y="emg_zygo",legend=False,title="Subject 23",color="tab:brown")
df24_phy.plot(ax=axes[3,5],x="time",y="emg_zygo",legend=False,title="Subject 24",color="tab:brown")
df25_phy.plot(ax=axes[4,0],x="time",y="emg_zygo",legend=False,title="Subject 25",color="tab:brown")
df26_phy.plot(ax=axes[4,1],x="time",y="emg_zygo",legend=False,title="Subject 26",color="tab:brown")
df27_phy.plot(ax=axes[4,2],x="time",y="emg_zygo",legend=False,title="Subject 27",color="tab:brown")
df28_phy.plot(ax=axes[4,3],x="time",y="emg_zygo",legend=False,title="Subject 28",color="tab:brown")
df29_phy.plot(ax=axes[4,4],x="time",y="emg_zygo",legend=False,title="Subject 29",color="tab:brown")
df30_phy.plot(ax=axes[4,5],x="time",y="emg_zygo",legend=False,title="Subject 30",color="tab:brown")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="emg_zygo",legend=False,title="Subject 1",color="tab:brown")
df2_phy.plot(ax=axes[0,1],x="time",y="emg_zygo",legend=False,title="Subject 2",color="tab:brown")
df3_phy.plot(ax=axes[0,2],x="time",y="emg_zygo",legend=False,title="Subject 3",color="tab:brown")
df4_phy.plot(ax=axes[0,3],x="time",y="emg_zygo",legend=False,title="Subject 4",color="tab:brown")
df5_phy.plot(ax=axes[0,4],x="time",y="emg_zygo",legend=False,title="Subject 5",color="tab:brown")
df6_phy.plot(ax=axes[0,5],x="time",y="emg_zygo",legend=False,title="Subject 6",color="tab:brown")
df7_phy.plot(ax=axes[1,0],x="time",y="emg_zygo",legend=False,title="Subject 7",color="tab:brown")
df8_phy.plot(ax=axes[1,1],x="time",y="emg_zygo",legend=False,title="Subject 8",color="tab:brown")
df9_phy.plot(ax=axes[1,2],x="time",y="emg_zygo",legend=False,title="Subject 9",color="tab:brown")
df10_phy.plot(ax=axes[1,3],x="time",y="emg_zygo",legend=False,title="Subject 10",color="tab:brown")
df11_phy.plot(ax=axes[1,4],x="time",y="emg_zygo",legend=False,title="Subject 11",color="tab:brown")
df12_phy.plot(ax=axes[1,5],x="time",y="emg_zygo",legend=False,title="Subject 12",color="tab:brown")
df13_phy.plot(ax=axes[2,0],x="time",y="emg_zygo",legend=False,title="Subject 13",color="tab:brown")
df14_phy.plot(ax=axes[2,1],x="time",y="emg_zygo",legend=False,title="Subject 14",color="tab:brown")
df15_phy.plot(ax=axes[2,2],x="time",y="emg_zygo",legend=False,title="Subject 15",color="tab:brown")
df16_phy.plot(ax=axes[2,3],x="time",y="emg_zygo",legend=False,title="Subject 16",color="tab:brown")
df17_phy.plot(ax=axes[2,4],x="time",y="emg_zygo",legend=False,title="Subject 17",color="tab:brown")
df18_phy.plot(ax=axes[2,5],x="time",y="emg_zygo",legend=False,title="Subject 18",color="tab:brown")
df19_phy.plot(ax=axes[3,0],x="time",y="emg_zygo",legend=False,title="Subject 19",color="tab:brown")
df20_phy.plot(ax=axes[3,1],x="time",y="emg_zygo",legend=False,title="Subject 20",color="tab:brown")
df21_phy.plot(ax=axes[3,2],x="time",y="emg_zygo",legend=False,title="Subject 21",color="tab:brown")
df22_phy.plot(ax=axes[3,3],x="time",y="emg_zygo",legend=False,title="Subject 22",color="tab:brown")
df23_phy.plot(ax=axes[3,4],x="time",y="emg_zygo",legend=False,title="Subject 23",color="tab:brown")
df24_phy.plot(ax=axes[3,5],x="time",y="emg_zygo",legend=False,title="Subject 24",color="tab:brown")
df25_phy.plot(ax=axes[4,0],x="time",y="emg_zygo",legend=False,title="Subject 25",color="tab:brown")
df26_phy.plot(ax=axes[4,1],x="time",y="emg_zygo",legend=False,title="Subject 26",color="tab:brown")
df27_phy.plot(ax=axes[4,2],x="time",y="emg_zygo",legend=False,title="Subject 27",color="tab:brown")
df28_phy.plot(ax=axes[4,3],x="time",y="emg_zygo",legend=False,title="Subject 28",color="tab:brown")
df29_phy.plot(ax=axes[4,4],x="time",y="emg_zygo",legend=False,title="Subject 29",color="tab:brown")
df30_phy.plot(ax=axes[4,5],x="time",y="emg_zygo",legend=False,title="Subject 30",color="tab:brown")
plt.setp(axes, xlim=(0,40000))
fig.tight_layout()

# %% [markdown]
# Variable emg_coru

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="emg_coru",legend=False,title="Subject 1",color="tab:pink")
df2_phy.plot(ax=axes[0,1],x="time",y="emg_coru",legend=False,title="Subject 2",color="tab:pink")
df3_phy.plot(ax=axes[0,2],x="time",y="emg_coru",legend=False,title="Subject 3",color="tab:pink")
df4_phy.plot(ax=axes[0,3],x="time",y="emg_coru",legend=False,title="Subject 4",color="tab:pink")
df5_phy.plot(ax=axes[0,4],x="time",y="emg_coru",legend=False,title="Subject 5",color="tab:pink")
df6_phy.plot(ax=axes[0,5],x="time",y="emg_coru",legend=False,title="Subject 6",color="tab:pink")
df7_phy.plot(ax=axes[1,0],x="time",y="emg_coru",legend=False,title="Subject 7",color="tab:pink")
df8_phy.plot(ax=axes[1,1],x="time",y="emg_coru",legend=False,title="Subject 8",color="tab:pink")
df9_phy.plot(ax=axes[1,2],x="time",y="emg_coru",legend=False,title="Subject 9",color="tab:pink")
df10_phy.plot(ax=axes[1,3],x="time",y="emg_coru",legend=False,title="Subject 10",color="tab:pink")
df11_phy.plot(ax=axes[1,4],x="time",y="emg_coru",legend=False,title="Subject 11",color="tab:pink")
df12_phy.plot(ax=axes[1,5],x="time",y="emg_coru",legend=False,title="Subject 12",color="tab:pink")
df13_phy.plot(ax=axes[2,0],x="time",y="emg_coru",legend=False,title="Subject 13",color="tab:pink")
df14_phy.plot(ax=axes[2,1],x="time",y="emg_coru",legend=False,title="Subject 14",color="tab:pink")
df15_phy.plot(ax=axes[2,2],x="time",y="emg_coru",legend=False,title="Subject 15",color="tab:pink")
df16_phy.plot(ax=axes[2,3],x="time",y="emg_coru",legend=False,title="Subject 16",color="tab:pink")
df17_phy.plot(ax=axes[2,4],x="time",y="emg_coru",legend=False,title="Subject 17",color="tab:pink")
df18_phy.plot(ax=axes[2,5],x="time",y="emg_coru",legend=False,title="Subject 18",color="tab:pink")
df19_phy.plot(ax=axes[3,0],x="time",y="emg_coru",legend=False,title="Subject 19",color="tab:pink")
df20_phy.plot(ax=axes[3,1],x="time",y="emg_coru",legend=False,title="Subject 20",color="tab:pink")
df21_phy.plot(ax=axes[3,2],x="time",y="emg_coru",legend=False,title="Subject 21",color="tab:pink")
df22_phy.plot(ax=axes[3,3],x="time",y="emg_coru",legend=False,title="Subject 22",color="tab:pink")
df23_phy.plot(ax=axes[3,4],x="time",y="emg_coru",legend=False,title="Subject 23",color="tab:pink")
df24_phy.plot(ax=axes[3,5],x="time",y="emg_coru",legend=False,title="Subject 24",color="tab:pink")
df25_phy.plot(ax=axes[4,0],x="time",y="emg_coru",legend=False,title="Subject 25",color="tab:pink")
df26_phy.plot(ax=axes[4,1],x="time",y="emg_coru",legend=False,title="Subject 26",color="tab:pink")
df27_phy.plot(ax=axes[4,2],x="time",y="emg_coru",legend=False,title="Subject 27",color="tab:pink")
df28_phy.plot(ax=axes[4,3],x="time",y="emg_coru",legend=False,title="Subject 28",color="tab:pink")
df29_phy.plot(ax=axes[4,4],x="time",y="emg_coru",legend=False,title="Subject 29",color="tab:pink")
df30_phy.plot(ax=axes[4,5],x="time",y="emg_coru",legend=False,title="Subject 30",color="tab:pink")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="emg_coru",legend=False,title="Subject 1",color="tab:pink")
df2_phy.plot(ax=axes[0,1],x="time",y="emg_coru",legend=False,title="Subject 2",color="tab:pink")
df3_phy.plot(ax=axes[0,2],x="time",y="emg_coru",legend=False,title="Subject 3",color="tab:pink")
df4_phy.plot(ax=axes[0,3],x="time",y="emg_coru",legend=False,title="Subject 4",color="tab:pink")
df5_phy.plot(ax=axes[0,4],x="time",y="emg_coru",legend=False,title="Subject 5",color="tab:pink")
df6_phy.plot(ax=axes[0,5],x="time",y="emg_coru",legend=False,title="Subject 6",color="tab:pink")
df7_phy.plot(ax=axes[1,0],x="time",y="emg_coru",legend=False,title="Subject 7",color="tab:pink")
df8_phy.plot(ax=axes[1,1],x="time",y="emg_coru",legend=False,title="Subject 8",color="tab:pink")
df9_phy.plot(ax=axes[1,2],x="time",y="emg_coru",legend=False,title="Subject 9",color="tab:pink")
df10_phy.plot(ax=axes[1,3],x="time",y="emg_coru",legend=False,title="Subject 10",color="tab:pink")
df11_phy.plot(ax=axes[1,4],x="time",y="emg_coru",legend=False,title="Subject 11",color="tab:pink")
df12_phy.plot(ax=axes[1,5],x="time",y="emg_coru",legend=False,title="Subject 12",color="tab:pink")
df13_phy.plot(ax=axes[2,0],x="time",y="emg_coru",legend=False,title="Subject 13",color="tab:pink")
df14_phy.plot(ax=axes[2,1],x="time",y="emg_coru",legend=False,title="Subject 14",color="tab:pink")
df15_phy.plot(ax=axes[2,2],x="time",y="emg_coru",legend=False,title="Subject 15",color="tab:pink")
df16_phy.plot(ax=axes[2,3],x="time",y="emg_coru",legend=False,title="Subject 16",color="tab:pink")
df17_phy.plot(ax=axes[2,4],x="time",y="emg_coru",legend=False,title="Subject 17",color="tab:pink")
df18_phy.plot(ax=axes[2,5],x="time",y="emg_coru",legend=False,title="Subject 18",color="tab:pink")
df19_phy.plot(ax=axes[3,0],x="time",y="emg_coru",legend=False,title="Subject 19",color="tab:pink")
df20_phy.plot(ax=axes[3,1],x="time",y="emg_coru",legend=False,title="Subject 20",color="tab:pink")
df21_phy.plot(ax=axes[3,2],x="time",y="emg_coru",legend=False,title="Subject 21",color="tab:pink")
df22_phy.plot(ax=axes[3,3],x="time",y="emg_coru",legend=False,title="Subject 22",color="tab:pink")
df23_phy.plot(ax=axes[3,4],x="time",y="emg_coru",legend=False,title="Subject 23",color="tab:pink")
df24_phy.plot(ax=axes[3,5],x="time",y="emg_coru",legend=False,title="Subject 24",color="tab:pink")
df25_phy.plot(ax=axes[4,0],x="time",y="emg_coru",legend=False,title="Subject 25",color="tab:pink")
df26_phy.plot(ax=axes[4,1],x="time",y="emg_coru",legend=False,title="Subject 26",color="tab:pink")
df27_phy.plot(ax=axes[4,2],x="time",y="emg_coru",legend=False,title="Subject 27",color="tab:pink")
df28_phy.plot(ax=axes[4,3],x="time",y="emg_coru",legend=False,title="Subject 28",color="tab:pink")
df29_phy.plot(ax=axes[4,4],x="time",y="emg_coru",legend=False,title="Subject 29",color="tab:pink")
df30_phy.plot(ax=axes[4,5],x="time",y="emg_coru",legend=False,title="Subject 30",color="tab:pink")
plt.setp(axes, xlim=(0,40000))
fig.tight_layout()

# %% [markdown]
# Variable emg_trap

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="emg_coru",legend=False,title="Subject 1",color="tab:gray")
df2_phy.plot(ax=axes[0,1],x="time",y="emg_coru",legend=False,title="Subject 2",color="tab:gray")
df3_phy.plot(ax=axes[0,2],x="time",y="emg_coru",legend=False,title="Subject 3",color="tab:gray")
df4_phy.plot(ax=axes[0,3],x="time",y="emg_coru",legend=False,title="Subject 4",color="tab:gray")
df5_phy.plot(ax=axes[0,4],x="time",y="emg_coru",legend=False,title="Subject 5",color="tab:gray")
df6_phy.plot(ax=axes[0,5],x="time",y="emg_coru",legend=False,title="Subject 6",color="tab:gray")
df7_phy.plot(ax=axes[1,0],x="time",y="emg_coru",legend=False,title="Subject 7",color="tab:gray")
df8_phy.plot(ax=axes[1,1],x="time",y="emg_coru",legend=False,title="Subject 8",color="tab:gray")
df9_phy.plot(ax=axes[1,2],x="time",y="emg_coru",legend=False,title="Subject 9",color="tab:gray")
df10_phy.plot(ax=axes[1,3],x="time",y="emg_coru",legend=False,title="Subject 10",color="tab:gray")
df11_phy.plot(ax=axes[1,4],x="time",y="emg_coru",legend=False,title="Subject 11",color="tab:gray")
df12_phy.plot(ax=axes[1,5],x="time",y="emg_coru",legend=False,title="Subject 12",color="tab:gray")
df13_phy.plot(ax=axes[2,0],x="time",y="emg_coru",legend=False,title="Subject 13",color="tab:gray")
df14_phy.plot(ax=axes[2,1],x="time",y="emg_coru",legend=False,title="Subject 14",color="tab:gray")
df15_phy.plot(ax=axes[2,2],x="time",y="emg_coru",legend=False,title="Subject 15",color="tab:gray")
df16_phy.plot(ax=axes[2,3],x="time",y="emg_coru",legend=False,title="Subject 16",color="tab:gray")
df17_phy.plot(ax=axes[2,4],x="time",y="emg_coru",legend=False,title="Subject 17",color="tab:gray")
df18_phy.plot(ax=axes[2,5],x="time",y="emg_coru",legend=False,title="Subject 18",color="tab:gray")
df19_phy.plot(ax=axes[3,0],x="time",y="emg_coru",legend=False,title="Subject 19",color="tab:gray")
df20_phy.plot(ax=axes[3,1],x="time",y="emg_coru",legend=False,title="Subject 20",color="tab:gray")
df21_phy.plot(ax=axes[3,2],x="time",y="emg_coru",legend=False,title="Subject 21",color="tab:gray")
df22_phy.plot(ax=axes[3,3],x="time",y="emg_coru",legend=False,title="Subject 22",color="tab:gray")
df23_phy.plot(ax=axes[3,4],x="time",y="emg_coru",legend=False,title="Subject 23",color="tab:gray")
df24_phy.plot(ax=axes[3,5],x="time",y="emg_coru",legend=False,title="Subject 24",color="tab:gray")
df25_phy.plot(ax=axes[4,0],x="time",y="emg_coru",legend=False,title="Subject 25",color="tab:gray")
df26_phy.plot(ax=axes[4,1],x="time",y="emg_coru",legend=False,title="Subject 26",color="tab:gray")
df27_phy.plot(ax=axes[4,2],x="time",y="emg_coru",legend=False,title="Subject 27",color="tab:gray")
df28_phy.plot(ax=axes[4,3],x="time",y="emg_coru",legend=False,title="Subject 28",color="tab:gray")
df29_phy.plot(ax=axes[4,4],x="time",y="emg_coru",legend=False,title="Subject 29",color="tab:gray")
df30_phy.plot(ax=axes[4,5],x="time",y="emg_coru",legend=False,title="Subject 30",color="tab:gray")
fig.tight_layout()

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_phy.plot(ax=axes[0,0],x="time",y="emg_coru",legend=False,title="Subject 1",color="tab:gray")
df2_phy.plot(ax=axes[0,1],x="time",y="emg_coru",legend=False,title="Subject 2",color="tab:gray")
df3_phy.plot(ax=axes[0,2],x="time",y="emg_coru",legend=False,title="Subject 3",color="tab:gray")
df4_phy.plot(ax=axes[0,3],x="time",y="emg_coru",legend=False,title="Subject 4",color="tab:gray")
df5_phy.plot(ax=axes[0,4],x="time",y="emg_coru",legend=False,title="Subject 5",color="tab:gray")
df6_phy.plot(ax=axes[0,5],x="time",y="emg_coru",legend=False,title="Subject 6",color="tab:gray")
df7_phy.plot(ax=axes[1,0],x="time",y="emg_coru",legend=False,title="Subject 7",color="tab:gray")
df8_phy.plot(ax=axes[1,1],x="time",y="emg_coru",legend=False,title="Subject 8",color="tab:gray")
df9_phy.plot(ax=axes[1,2],x="time",y="emg_coru",legend=False,title="Subject 9",color="tab:gray")
df10_phy.plot(ax=axes[1,3],x="time",y="emg_coru",legend=False,title="Subject 10",color="tab:gray")
df11_phy.plot(ax=axes[1,4],x="time",y="emg_coru",legend=False,title="Subject 11",color="tab:gray")
df12_phy.plot(ax=axes[1,5],x="time",y="emg_coru",legend=False,title="Subject 12",color="tab:gray")
df13_phy.plot(ax=axes[2,0],x="time",y="emg_coru",legend=False,title="Subject 13",color="tab:gray")
df14_phy.plot(ax=axes[2,1],x="time",y="emg_coru",legend=False,title="Subject 14",color="tab:gray")
df15_phy.plot(ax=axes[2,2],x="time",y="emg_coru",legend=False,title="Subject 15",color="tab:gray")
df16_phy.plot(ax=axes[2,3],x="time",y="emg_coru",legend=False,title="Subject 16",color="tab:gray")
df17_phy.plot(ax=axes[2,4],x="time",y="emg_coru",legend=False,title="Subject 17",color="tab:gray")
df18_phy.plot(ax=axes[2,5],x="time",y="emg_coru",legend=False,title="Subject 18",color="tab:gray")
df19_phy.plot(ax=axes[3,0],x="time",y="emg_coru",legend=False,title="Subject 19",color="tab:gray")
df20_phy.plot(ax=axes[3,1],x="time",y="emg_coru",legend=False,title="Subject 20",color="tab:gray")
df21_phy.plot(ax=axes[3,2],x="time",y="emg_coru",legend=False,title="Subject 21",color="tab:gray")
df22_phy.plot(ax=axes[3,3],x="time",y="emg_coru",legend=False,title="Subject 22",color="tab:gray")
df23_phy.plot(ax=axes[3,4],x="time",y="emg_coru",legend=False,title="Subject 23",color="tab:gray")
df24_phy.plot(ax=axes[3,5],x="time",y="emg_coru",legend=False,title="Subject 24",color="tab:gray")
df25_phy.plot(ax=axes[4,0],x="time",y="emg_coru",legend=False,title="Subject 25",color="tab:gray")
df26_phy.plot(ax=axes[4,1],x="time",y="emg_coru",legend=False,title="Subject 26",color="tab:gray")
df27_phy.plot(ax=axes[4,2],x="time",y="emg_coru",legend=False,title="Subject 27",color="tab:gray")
df28_phy.plot(ax=axes[4,3],x="time",y="emg_coru",legend=False,title="Subject 28",color="tab:gray")
df29_phy.plot(ax=axes[4,4],x="time",y="emg_coru",legend=False,title="Subject 29",color="tab:gray")
df30_phy.plot(ax=axes[4,5],x="time",y="emg_coru",legend=False,title="Subject 30",color="tab:gray")
plt.setp(axes, xlim=(0,40000))
fig.tight_layout()

# %% [markdown]
# Arousal y Valence

# %%
fig, axes = plt.subplots(nrows=5, ncols=6,figsize=(12,10))
df1_ann.plot(ax=axes[0,0],x="time",y=["arousal","valence"],legend=False,title="Subject 1")
df2_ann.plot(ax=axes[0,1],x="time",y=["arousal","valence"],legend=False,title="Subject 2")
df3_ann.plot(ax=axes[0,2],x="time",y=["arousal","valence"],legend=False,title="Subject 3")
df4_ann.plot(ax=axes[0,3],x="time",y=["arousal","valence"],legend=False,title="Subject 4")
df5_ann.plot(ax=axes[0,4],x="time",y=["arousal","valence"],legend=False,title="Subject 5")
df6_ann.plot(ax=axes[0,5],x="time",y=["arousal","valence"],legend=False,title="Subject 6")
df7_ann.plot(ax=axes[1,0],x="time",y=["arousal","valence"],legend=False,title="Subject 7")
df8_ann.plot(ax=axes[1,1],x="time",y=["arousal","valence"],legend=False,title="Subject 8")
df9_ann.plot(ax=axes[1,2],x="time",y=["arousal","valence"],legend=False,title="Subject 9")
df10_ann.plot(ax=axes[1,3],x="time",y=["arousal","valence"],legend=False,title="Subject 10")
df11_ann.plot(ax=axes[1,4],x="time",y=["arousal","valence"],legend=False,title="Subject 11")
df12_ann.plot(ax=axes[1,5],x="time",y=["arousal","valence"],legend=False,title="Subject 12")
df13_ann.plot(ax=axes[2,0],x="time",y=["arousal","valence"],legend=False,title="Subject 13")
df14_ann.plot(ax=axes[2,1],x="time",y=["arousal","valence"],legend=False,title="Subject 14")
df15_ann.plot(ax=axes[2,2],x="time",y=["arousal","valence"],legend=False,title="Subject 15")
df16_ann.plot(ax=axes[2,3],x="time",y=["arousal","valence"],legend=False,title="Subject 16")
df17_ann.plot(ax=axes[2,4],x="time",y=["arousal","valence"],legend=False,title="Subject 17")
df18_ann.plot(ax=axes[2,5],x="time",y=["arousal","valence"],legend=False,title="Subject 18")
axes[2,5].legend(loc='upper left',bbox_to_anchor=(1.1, 1.05))
df19_ann.plot(ax=axes[3,0],x="time",y=["arousal","valence"],legend=False,title="Subject 19")
df20_ann.plot(ax=axes[3,1],x="time",y=["arousal","valence"],legend=False,title="Subject 20")
df21_ann.plot(ax=axes[3,2],x="time",y=["arousal","valence"],legend=False,title="Subject 21")
df22_ann.plot(ax=axes[3,3],x="time",y=["arousal","valence"],legend=False,title="Subject 22")
df23_ann.plot(ax=axes[3,4],x="time",y=["arousal","valence"],legend=False,title="Subject 23")
df24_ann.plot(ax=axes[3,5],x="time",y=["arousal","valence"],legend=False,title="Subject 24")
df25_ann.plot(ax=axes[4,0],x="time",y=["arousal","valence"],legend=False,title="Subject 25")
df26_ann.plot(ax=axes[4,1],x="time",y=["arousal","valence"],legend=False,title="Subject 26")
df27_ann.plot(ax=axes[4,2],x="time",y=["arousal","valence"],legend=False,title="Subject 27")
df28_ann.plot(ax=axes[4,3],x="time",y=["arousal","valence"],legend=False,title="Subject 28")
df29_ann.plot(ax=axes[4,4],x="time",y=["arousal","valence"],legend=False,title="Subject 29")
df30_ann.plot(ax=axes[4,5],x="time",y=["arousal","valence"],legend=False,title="Subject 30")


fig.tight_layout()

# %% [markdown]
# ## Parte 2, Después del procesamiento

# %%
df1_2a=pd.read_csv('Output/arousal_2_clases_sub1.csv')
df1_2v=pd.read_csv('Output/valence_2_clases_sub1.csv')
df1_3a=pd.read_csv('Output/arousal_3_clases_sub1.csv')
df1_3v=pd.read_csv('Output/valence_3_clases_sub1.csv')
df1_4=pd.read_csv('Output/valencearousal_4_clases_sub1.csv')
df2_2a=pd.read_csv('Output/arousal_2_clases_sub2.csv')
df2_2v=pd.read_csv('Output/valence_2_clases_sub2.csv')
df2_3a=pd.read_csv('Output/arousal_3_clases_sub2.csv')
df2_3v=pd.read_csv('Output/valence_3_clases_sub2.csv')
df2_4=pd.read_csv('Output/valencearousal_4_clases_sub2.csv')
df3_2a=pd.read_csv('Output/arousal_2_clases_sub3.csv')
df3_2v=pd.read_csv('Output/valence_2_clases_sub3.csv')
df3_3a=pd.read_csv('Output/arousal_3_clases_sub3.csv')
df3_3v=pd.read_csv('Output/valence_3_clases_sub3.csv')
df3_4=pd.read_csv('Output/valencearousal_4_clases_sub3.csv')
df4_2a=pd.read_csv('Output/arousal_2_clases_sub4.csv')
df4_2v=pd.read_csv('Output/valence_2_clases_sub4.csv')
df4_3a=pd.read_csv('Output/arousal_3_clases_sub4.csv')
df4_3v=pd.read_csv('Output/valence_3_clases_sub4.csv')
df4_4=pd.read_csv('Output/valencearousal_4_clases_sub4.csv')
df5_2a=pd.read_csv('Output/arousal_2_clases_sub5.csv')
df5_2v=pd.read_csv('Output/valence_2_clases_sub5.csv')
df5_3a=pd.read_csv('Output/arousal_3_clases_sub5.csv')
df5_3v=pd.read_csv('Output/valence_3_clases_sub5.csv')
df5_4=pd.read_csv('Output/valencearousal_4_clases_sub5.csv')
df6_2a=pd.read_csv('Output/arousal_2_clases_sub6.csv')
df6_2v=pd.read_csv('Output/valence_2_clases_sub6.csv')
df6_3a=pd.read_csv('Output/arousal_3_clases_sub6.csv')
df6_3v=pd.read_csv('Output/valence_3_clases_sub6.csv')
df6_4=pd.read_csv('Output/valencearousal_4_clases_sub6.csv')
df7_2a=pd.read_csv('Output/arousal_2_clases_sub7.csv')
df7_2v=pd.read_csv('Output/valence_2_clases_sub7.csv')
df7_3a=pd.read_csv('Output/arousal_3_clases_sub7.csv')
df7_3v=pd.read_csv('Output/valence_3_clases_sub7.csv')
df7_4=pd.read_csv('Output/valencearousal_4_clases_sub7.csv')
df8_2a=pd.read_csv('Output/arousal_2_clases_sub8.csv')
df8_2v=pd.read_csv('Output/valence_2_clases_sub8.csv')
df8_3a=pd.read_csv('Output/arousal_3_clases_sub8.csv')
df8_3v=pd.read_csv('Output/valence_3_clases_sub8.csv')
df8_4=pd.read_csv('Output/valencearousal_4_clases_sub8.csv')
df9_2a=pd.read_csv('Output/arousal_2_clases_sub9.csv')
df9_2v=pd.read_csv('Output/valence_2_clases_sub9.csv')
df9_3a=pd.read_csv('Output/arousal_3_clases_sub9.csv')
df9_3v=pd.read_csv('Output/valence_3_clases_sub9.csv')
df9_4=pd.read_csv('Output/valencearousal_4_clases_sub9.csv')
df10_2a=pd.read_csv('Output/arousal_2_clases_sub10.csv')
df10_2v=pd.read_csv('Output/valence_2_clases_sub10.csv')
df10_3a=pd.read_csv('Output/arousal_3_clases_sub10.csv')
df10_3v=pd.read_csv('Output/valence_3_clases_sub10.csv')
df10_4=pd.read_csv('Output/valencearousal_4_clases_sub10.csv')
df11_2a=pd.read_csv('Output/arousal_2_clases_sub11.csv')
df11_2v=pd.read_csv('Output/valence_2_clases_sub11.csv')
df11_3a=pd.read_csv('Output/arousal_3_clases_sub11.csv')
df11_3v=pd.read_csv('Output/valence_3_clases_sub11.csv')
df11_4=pd.read_csv('Output/valencearousal_4_clases_sub11.csv')
df12_2a=pd.read_csv('Output/arousal_2_clases_sub12.csv')
df12_2v=pd.read_csv('Output/valence_2_clases_sub12.csv')
df12_3a=pd.read_csv('Output/arousal_3_clases_sub12.csv')
df12_3v=pd.read_csv('Output/valence_3_clases_sub12.csv')
df12_4=pd.read_csv('Output/valencearousal_4_clases_sub12.csv')
df13_2a=pd.read_csv('Output/arousal_2_clases_sub13.csv')
df13_2v=pd.read_csv('Output/valence_2_clases_sub13.csv')
df13_3a=pd.read_csv('Output/arousal_3_clases_sub13.csv')
df13_3v=pd.read_csv('Output/valence_3_clases_sub13.csv')
df13_4=pd.read_csv('Output/valencearousal_4_clases_sub13.csv')
df14_2a=pd.read_csv('Output/arousal_2_clases_sub1.csv')
df14_2v=pd.read_csv('Output/valence_2_clases_sub14.csv')
df14_3a=pd.read_csv('Output/arousal_3_clases_sub14.csv')
df14_3v=pd.read_csv('Output/valence_3_clases_sub14.csv')
df14_4=pd.read_csv('Output/valencearousal_4_clases_sub14.csv')
df15_2a=pd.read_csv('Output/arousal_2_clases_sub15.csv')
df15_2v=pd.read_csv('Output/valence_2_clases_sub15.csv')
df15_3a=pd.read_csv('Output/arousal_3_clases_sub15.csv')
df15_3v=pd.read_csv('Output/valence_3_clases_sub15.csv')
df15_4=pd.read_csv('Output/valencearousal_4_clases_sub15.csv')
df16_2a=pd.read_csv('Output/arousal_2_clases_sub16.csv')
df16_2v=pd.read_csv('Output/valence_2_clases_sub16.csv')
df16_3a=pd.read_csv('Output/arousal_3_clases_sub16.csv')
df16_3v=pd.read_csv('Output/valence_3_clases_sub16.csv')
df16_4=pd.read_csv('Output/valencearousal_4_clases_sub16.csv')
df17_2a=pd.read_csv('Output/arousal_2_clases_sub17.csv')
df17_2v=pd.read_csv('Output/valence_2_clases_sub17.csv')
df17_3a=pd.read_csv('Output/arousal_3_clases_sub17.csv')
df17_3v=pd.read_csv('Output/valence_3_clases_sub17.csv')
df17_4=pd.read_csv('Output/valencearousal_4_clases_sub17.csv')
df18_2a=pd.read_csv('Output/arousal_2_clases_sub18.csv')
df18_2v=pd.read_csv('Output/valence_2_clases_sub18.csv')
df18_3a=pd.read_csv('Output/arousal_3_clases_sub18.csv')
df18_3v=pd.read_csv('Output/valence_3_clases_sub18.csv')
df18_4=pd.read_csv('Output/valencearousal_4_clases_sub18.csv')
df19_2a=pd.read_csv('Output/arousal_2_clases_sub19.csv')
df19_2v=pd.read_csv('Output/valence_2_clases_sub19.csv')
df19_3a=pd.read_csv('Output/arousal_3_clases_sub19.csv')
df19_3v=pd.read_csv('Output/valence_3_clases_sub19.csv')
df19_4=pd.read_csv('Output/valencearousal_4_clases_sub19.csv')
df20_2a=pd.read_csv('Output/arousal_2_clases_sub20.csv')
df20_2v=pd.read_csv('Output/valence_2_clases_sub20.csv')
df20_3a=pd.read_csv('Output/arousal_3_clases_sub20.csv')
df20_3v=pd.read_csv('Output/valence_3_clases_sub20.csv')
df20_4=pd.read_csv('Output/valencearousal_4_clases_sub20.csv')
df21_2a=pd.read_csv('Output/arousal_2_clases_sub21.csv')
df21_2v=pd.read_csv('Output/valence_2_clases_sub21.csv')
df21_3a=pd.read_csv('Output/arousal_3_clases_sub21.csv')
df21_3v=pd.read_csv('Output/valence_3_clases_sub21.csv')
df21_4=pd.read_csv('Output/valencearousal_4_clases_sub21.csv')
df22_2a=pd.read_csv('Output/arousal_2_clases_sub22.csv')
df22_2v=pd.read_csv('Output/valence_2_clases_sub22.csv')
df22_3a=pd.read_csv('Output/arousal_3_clases_sub22.csv')
df22_3v=pd.read_csv('Output/valence_3_clases_sub22.csv')
df22_4=pd.read_csv('Output/valencearousal_4_clases_sub22.csv')
df23_2a=pd.read_csv('Output/arousal_2_clases_sub23.csv')
df23_2v=pd.read_csv('Output/valence_2_clases_sub23.csv')
df23_3a=pd.read_csv('Output/arousal_3_clases_sub23.csv')
df23_3v=pd.read_csv('Output/valence_3_clases_sub23.csv')
df23_4=pd.read_csv('Output/valencearousal_4_clases_sub23.csv')
df24_2a=pd.read_csv('Output/arousal_2_clases_sub24.csv')
df24_2v=pd.read_csv('Output/valence_2_clases_sub24.csv')
df24_3a=pd.read_csv('Output/arousal_3_clases_sub24.csv')
df24_3v=pd.read_csv('Output/valence_3_clases_sub24.csv')
df24_4=pd.read_csv('Output/valencearousal_4_clases_sub24.csv')
df25_2a=pd.read_csv('Output/arousal_2_clases_sub25.csv')
df25_2v=pd.read_csv('Output/valence_2_clases_sub25.csv')
df25_3a=pd.read_csv('Output/arousal_3_clases_sub25.csv')
df25_3v=pd.read_csv('Output/valence_3_clases_sub25.csv')
df25_4=pd.read_csv('Output/valencearousal_4_clases_sub25.csv')
df26_2a=pd.read_csv('Output/arousal_2_clases_sub26.csv')
df26_2v=pd.read_csv('Output/valence_2_clases_sub26.csv')
df26_3a=pd.read_csv('Output/arousal_3_clases_sub26.csv')
df26_3v=pd.read_csv('Output/valence_3_clases_sub26.csv')
df26_4=pd.read_csv('Output/valencearousal_4_clases_sub26.csv')
df27_2a=pd.read_csv('Output/arousal_2_clases_sub27.csv')
df27_2v=pd.read_csv('Output/valence_2_clases_sub27.csv')
df27_3a=pd.read_csv('Output/arousal_3_clases_sub27.csv')
df27_3v=pd.read_csv('Output/valence_3_clases_sub27.csv')
df27_4=pd.read_csv('Output/valencearousal_4_clases_sub27.csv')
df28_2a=pd.read_csv('Output/arousal_2_clases_sub28.csv')
df28_2v=pd.read_csv('Output/valence_2_clases_sub28.csv')
df28_3a=pd.read_csv('Output/arousal_3_clases_sub28.csv')
df28_3v=pd.read_csv('Output/valence_3_clases_sub28.csv')
df28_4=pd.read_csv('Output/valencearousal_4_clases_sub28.csv')
df29_2a=pd.read_csv('Output/arousal_2_clases_sub29.csv')
df29_2v=pd.read_csv('Output/valence_2_clases_sub29.csv')
df29_3a=pd.read_csv('Output/arousal_3_clases_sub29.csv')
df29_3v=pd.read_csv('Output/valence_3_clases_sub29.csv')
df29_4=pd.read_csv('Output/valencearousal_4_clases_sub29.csv')
df30_2a=pd.read_csv('Output/arousal_2_clases_sub30.csv')
df30_2v=pd.read_csv('Output/valence_2_clases_sub30.csv')
df30_3a=pd.read_csv('Output/arousal_3_clases_sub30.csv')
df30_3v=pd.read_csv('Output/valence_3_clases_sub30.csv')
df30_4=pd.read_csv('Output/valencearousal_4_clases_sub30.csv')

# %% [markdown]
# Arousal 2 clases

# %%
df1_2a=df1_2a["arousal"]
var1_1=len(df1_2a[df1_2a==1])
var2_1=len(df1_2a[df1_2a==2])
df2_2a=df2_2a["arousal"]
var1_2=len(df2_2a[df2_2a==1])
var2_2=len(df2_2a[df2_2a==2])
df3_2a=df3_2a["arousal"]
var1_3=len(df3_2a[df3_2a==1])
var2_3=len(df3_2a[df3_2a==2])
df4_2a=df4_2a["arousal"]
var1_4=len(df4_2a[df4_2a==1])
var2_4=len(df4_2a[df4_2a==2])
df5_2a=df5_2a["arousal"]
var1_5=len(df5_2a[df5_2a==1])
var2_5=len(df5_2a[df5_2a==2])
df6_2a=df6_2a["arousal"]
var1_6=len(df6_2a[df6_2a==1])
var2_6=len(df6_2a[df6_2a==2])
df7_2a=df7_2a["arousal"]
var1_7=len(df7_2a[df7_2a==1])
var2_7=len(df7_2a[df7_2a==2])
df8_2a=df8_2a["arousal"]
var1_8=len(df8_2a[df8_2a==1])
var2_8=len(df8_2a[df8_2a==2])
df9_2a=df9_2a["arousal"]
var1_9=len(df9_2a[df9_2a==1])
var2_9=len(df9_2a[df9_2a==2])
df10_2a=df10_2a["arousal"]
var1_10=len(df10_2a[df10_2a==1])
var2_10=len(df10_2a[df10_2a==2])
df11_2a=df11_2a["arousal"]
var1_11=len(df11_2a[df11_2a==1])
var2_11=len(df11_2a[df11_2a==2])
df12_2a=df12_2a["arousal"]
var1_12=len(df12_2a[df12_2a==1])
var2_12=len(df12_2a[df12_2a==2])
df13_2a=df13_2a["arousal"]
var1_13=len(df13_2a[df13_2a==1])
var2_13=len(df13_2a[df13_2a==2])
df14_2a=df14_2a["arousal"]
var1_14=len(df14_2a[df14_2a==1])
var2_14=len(df14_2a[df14_2a==2])
df15_2a=df15_2a["arousal"]
var1_15=len(df15_2a[df15_2a==1])
var2_15=len(df15_2a[df15_2a==2])
df16_2a=df16_2a["arousal"]
var1_16=len(df16_2a[df16_2a==1])
var2_16=len(df16_2a[df16_2a==2])
df17_2a=df17_2a["arousal"]
var1_17=len(df17_2a[df17_2a==1])
var2_17=len(df17_2a[df17_2a==2])
df18_2a=df18_2a["arousal"]
var1_18=len(df18_2a[df18_2a==1])
var2_18=len(df18_2a[df18_2a==2])
df19_2a=df19_2a["arousal"]
var1_19=len(df19_2a[df19_2a==1])
var2_19=len(df19_2a[df19_2a==2])
df20_2a=df20_2a["arousal"]
var1_20=len(df20_2a[df20_2a==1])
var2_20=len(df20_2a[df20_2a==2])
df21_2a=df21_2a["arousal"]
var1_21=len(df21_2a[df21_2a==1])
var2_21=len(df21_2a[df21_2a==2])
df22_2a=df22_2a["arousal"]
var1_22=len(df22_2a[df22_2a==1])
var2_22=len(df22_2a[df22_2a==2])
df23_2a=df23_2a["arousal"]
var1_23=len(df23_2a[df23_2a==1])
var2_23=len(df23_2a[df23_2a==2])
df24_2a=df24_2a["arousal"]
var1_24=len(df24_2a[df24_2a==1])
var2_24=len(df24_2a[df24_2a==2])
df25_2a=df25_2a["arousal"]
var1_25=len(df25_2a[df25_2a==1])
var2_25=len(df25_2a[df25_2a==2])
df26_2a=df26_2a["arousal"]
var1_26=len(df26_2a[df26_2a==1])
var2_26=len(df26_2a[df26_2a==2])
df27_2a=df27_2a["arousal"]
var1_27=len(df27_2a[df27_2a==1])
var2_27=len(df27_2a[df27_2a==2])
df28_2a=df28_2a["arousal"]
var1_28=len(df28_2a[df28_2a==1])
var2_28=len(df28_2a[df28_2a==2])
df29_2a=df29_2a["arousal"]
var1_29=len(df29_2a[df29_2a==1])
var2_29=len(df29_2a[df29_2a==2])
df30_2a=df30_2a["arousal"]
var1_30=len(df30_2a[df30_2a==1])
var2_30=len(df30_2a[df30_2a==2])
d = pd.DataFrame({'name': ["Subject 1","Subject 2","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 26","Subject 27","Subject 28","Subject 29","Subject 30"], '1': [var1_1,var1_2,var1_3,var1_4,var1_5,var1_6,var1_7,var1_8,var1_9,var1_10,var1_11,var1_12,var1_13,var1_14,var1_15,var1_16,var1_17,var1_18,var1_19,var1_20,var1_21,var1_22,var1_23,var1_24,var1_25,var1_26,var1_27,var1_28,var1_29,var1_30],'2': [var2_1,var2_2,var2_3,var2_4,var2_5,var2_6,var2_7,var2_8,var2_9,var2_10,var2_11,var2_12,var2_13,var2_14,var2_15,var2_16,var2_17,var2_18,var2_19,var2_20,var2_21,var2_22,var2_23,var2_24,var2_25,var2_26,var2_27,var2_28,var2_29,var2_30]})
d=d.reindex(columns=["name","2","1"])
d
# Out:
#           name     2     1
# 0    Subject 1  1986   554
# 1    Subject 2  1511  1029
# 2    Subject 3  1407  1133
# 3    Subject 4  1944   596
# 4    Subject 5  1272  1268
# 5    Subject 6  1468  1072
# 6    Subject 7  1956   584
# 7    Subject 8  1557   983
# 8    Subject 9   986  1554
# 9   Subject 10  1563   977
# 10  Subject 11  1226  1314
# 11  Subject 12  1997   543
# 12  Subject 13  1791   749
# 13  Subject 14  1986   554
# 14  Subject 15  1663   877
# 15  Subject 16  1523  1017
# 16  Subject 17  1060  1480
# 17  Subject 18  1767   773
# 18  Subject 19  2337   203
# 19  Subject 20  1757   783
# 20  Subject 21  1835   705
# 21  Subject 22  2089   451
# 22  Subject 23  1035  1505
# 23  Subject 24  1689   851
# 24  Subject 25  1535  1005
# 25  Subject 26  1808   732
# 26  Subject 27  1291  1249
# 27  Subject 28  1711   829
# 28  Subject 29  2207   333
# 29  Subject 30  1783   757

# %%
d.plot(x="name",stacked = True,kind = 'barh', width=0.8, ylabel="")
plt.legend(fontsize=6,loc="lower left")
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.ylabel("")

df_total = d["1"] + d["2"]
df_rel = d[d.columns[1:]].div(df_total, 0) * 100
  
for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(d.iloc[:, 1:].cumsum(1)[n], 
                                         d[n], df_rel[n])):
        plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'left', fontsize = 6,color="k")

# %% [markdown]
# Valence 2 clases

# %%
df1_2v=df1_2v["valence"]
var1_1=len(df1_2v[df1_2v==1])
var2_1=len(df1_2v[df1_2v==2])
df2_2v=df2_2v["valence"]
var1_2=len(df2_2v[df2_2v==1])
var2_2=len(df2_2v[df2_2v==2])
df3_2v=df3_2v["valence"]
var1_3=len(df3_2v[df3_2v==1])
var2_3=len(df3_2v[df3_2v==2])
df4_2v=df4_2v["valence"]
var1_4=len(df4_2v[df4_2v==1])
var2_4=len(df4_2v[df4_2v==2])
df5_2v=df5_2v["valence"]
var1_5=len(df5_2v[df5_2v==1])
var2_5=len(df5_2v[df5_2v==2])
df6_2v=df6_2v["valence"]
var1_6=len(df6_2v[df6_2v==1])
var2_6=len(df6_2v[df6_2v==2])
df7_2v=df7_2v["valence"]
var1_7=len(df7_2v[df7_2v==1])
var2_7=len(df7_2v[df7_2v==2])
df8_2v=df8_2v["valence"]
var1_8=len(df8_2v[df8_2v==1])
var2_8=len(df8_2v[df8_2v==2])
df9_2v=df9_2v["valence"]
var1_9=len(df9_2v[df9_2v==1])
var2_9=len(df9_2v[df9_2v==2])
df10_2v=df10_2v["valence"]
var1_10=len(df10_2v[df10_2v==1])
var2_10=len(df10_2v[df10_2v==2])
df11_2v=df11_2v["valence"]
var1_11=len(df11_2v[df11_2v==1])
var2_11=len(df11_2v[df11_2v==2])
df12_2v=df12_2v["valence"]
var1_12=len(df12_2v[df12_2v==1])
var2_12=len(df12_2v[df12_2v==2])
df13_2v=df13_2v["valence"]
var1_13=len(df13_2v[df13_2v==1])
var2_13=len(df13_2v[df13_2v==2])
df14_2v=df14_2v["valence"]
var1_14=len(df14_2v[df14_2v==1])
var2_14=len(df14_2v[df14_2v==2])
df15_2v=df15_2v["valence"]
var1_15=len(df15_2v[df15_2v==1])
var2_15=len(df15_2v[df15_2v==2])
df16_2v=df16_2v["valence"]
var1_16=len(df16_2v[df16_2v==1])
var2_16=len(df16_2v[df16_2v==2])
df17_2v=df17_2v["valence"]
var1_17=len(df17_2v[df17_2v==1])
var2_17=len(df17_2v[df17_2v==2])
df18_2v=df18_2v["valence"]
var1_18=len(df18_2v[df18_2v==1])
var2_18=len(df18_2v[df18_2v==2])
df19_2v=df19_2v["valence"]
var1_19=len(df19_2v[df19_2v==1])
var2_19=len(df19_2v[df19_2v==2])
df20_2v=df20_2v["valence"]
var1_20=len(df20_2v[df20_2v==1])
var2_20=len(df20_2v[df20_2v==2])
df21_2v=df21_2v["valence"]
var1_21=len(df21_2v[df21_2v==1])
var2_21=len(df21_2v[df21_2v==2])
df22_2v=df22_2v["valence"]
var1_22=len(df22_2v[df22_2v==1])
var2_22=len(df22_2v[df22_2v==2])
df23_2v=df23_2v["valence"]
var1_23=len(df23_2v[df23_2v==1])
var2_23=len(df23_2v[df23_2v==2])
df24_2v=df24_2v["valence"]
var1_24=len(df24_2v[df24_2v==1])
var2_24=len(df24_2v[df24_2v==2])
df25_2v=df25_2v["valence"]
var1_25=len(df25_2v[df25_2v==1])
var2_25=len(df25_2v[df25_2v==2])
df26_2v=df26_2v["valence"]
var1_26=len(df26_2v[df26_2v==1])
var2_26=len(df26_2v[df26_2v==2])
df27_2v=df27_2v["valence"]
var1_27=len(df27_2v[df27_2v==1])
var2_27=len(df27_2v[df27_2v==2])
df28_2v=df28_2v["valence"]
var1_28=len(df28_2v[df28_2v==1])
var2_28=len(df28_2v[df28_2v==2])
df29_2v=df29_2v["valence"]
var1_29=len(df29_2v[df29_2v==1])
var2_29=len(df29_2v[df29_2v==2])
df30_2v=df30_2v["valence"]
var1_30=len(df30_2v[df30_2v==1])
var2_30=len(df30_2v[df30_2v==2])
d = pd.DataFrame({'name': ["Subject 1","Subject 2","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 26","Subject 27","Subject 28","Subject 29","Subject 30"], '1': [var1_1,var1_2,var1_3,var1_4,var1_5,var1_6,var1_7,var1_8,var1_9,var1_10,var1_11,var1_12,var1_13,var1_14,var1_15,var1_16,var1_17,var1_18,var1_19,var1_20,var1_21,var1_22,var1_23,var1_24,var1_25,var1_26,var1_27,var1_28,var1_29,var1_30],'2': [var2_1,var2_2,var2_3,var2_4,var2_5,var2_6,var2_7,var2_8,var2_9,var2_10,var2_11,var2_12,var2_13,var2_14,var2_15,var2_16,var2_17,var2_18,var2_19,var2_20,var2_21,var2_22,var2_23,var2_24,var2_25,var2_26,var2_27,var2_28,var2_29,var2_30]})
d=d.reindex(columns=["name","2","1"])
d
# Out:
#           name     2     1
# 0    Subject 1  1541   999
# 1    Subject 2  1657   883
# 2    Subject 3  1626   914
# 3    Subject 4  1515  1025
# 4    Subject 5  1603   937
# 5    Subject 6  1653   887
# 6    Subject 7  1987   553
# 7    Subject 8  1749   791
# 8    Subject 9  1972   568
# 9   Subject 10  1731   809
# 10  Subject 11  1926   614
# 11  Subject 12  1947   593
# 12  Subject 13  1717   823
# 13  Subject 14  2154   386
# 14  Subject 15  1837   703
# 15  Subject 16  1699   841
# 16  Subject 17  1088  1452
# 17  Subject 18  2395   145
# 18  Subject 19  1761   779
# 19  Subject 20  1856   684
# 20  Subject 21  1342  1198
# 21  Subject 22  1734   806
# 22  Subject 23  1461  1079
# 23  Subject 24  1775   765
# 24  Subject 25  1396  1144
# 25  Subject 26  1621   919
# 26  Subject 27  1781   759
# 27  Subject 28  1577   963
# 28  Subject 29  2125   415
# 29  Subject 30  1725   815

# %%
d.plot(x="name",stacked = True,kind = 'barh', width=0.8, ylabel="")
plt.legend(fontsize=6,loc="lower left")
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.ylabel("")

df_total = d["1"] + d["2"]
df_rel = d[d.columns[1:]].div(df_total, 0) * 100
  
for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(d.iloc[:, 1:].cumsum(1)[n], 
                                         d[n], df_rel[n])):
        plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'left', fontsize = 6,color="k")

# %% [markdown]
# Arousal 3 clases

# %%
df1_3a=df1_3a["arousal"]
var1_1=len(df1_3a[df1_3a==1])
var2_1=len(df1_3a[df1_3a==2])
var3_1=len(df1_3a[df1_3a==3])
df2_3a=df2_3a["arousal"]
var1_2=len(df2_3a[df2_3a==1])
var2_2=len(df2_3a[df2_3a==2])
var3_2=len(df2_3a[df2_3a==3])
df3_3a=df3_3a["arousal"]
var1_3=len(df3_3a[df3_3a==1])
var2_3=len(df3_3a[df3_3a==2])
var3_3=len(df3_3a[df3_3a==3])
df4_3a=df4_3a["arousal"]
var1_4=len(df4_3a[df4_3a==1])
var2_4=len(df4_3a[df4_3a==2])
var3_4=len(df4_3a[df4_3a==3])
df5_3a=df5_3a["arousal"]
var1_5=len(df5_3a[df5_3a==1])
var2_5=len(df5_3a[df5_3a==2])
var3_5=len(df5_3a[df5_3a==3])
df6_3a=df6_3a["arousal"]
var1_6=len(df6_3a[df6_3a==1])
var2_6=len(df6_3a[df6_3a==2])
var3_6=len(df6_3a[df6_3a==3])
df7_3a=df7_3a["arousal"]
var1_7=len(df7_3a[df7_3a==1])
var2_7=len(df7_3a[df7_3a==2])
var3_7=len(df7_3a[df7_3a==3])
df8_3a=df8_3a["arousal"]
var1_8=len(df8_3a[df8_3a==1])
var2_8=len(df8_3a[df8_3a==2])
var3_8=len(df8_3a[df8_3a==3])
df9_3a=df9_3a["arousal"]
var1_9=len(df9_3a[df9_3a==1])
var2_9=len(df9_3a[df9_3a==2])
var3_9=len(df9_3a[df9_3a==3])
df10_3a=df10_3a["arousal"]
var1_10=len(df10_3a[df10_3a==1])
var2_10=len(df10_3a[df10_3a==2])
var3_10=len(df10_3a[df10_3a==3])
df11_3a=df11_3a["arousal"]
var1_11=len(df11_3a[df11_3a==1])
var2_11=len(df11_3a[df11_3a==2])
var3_11=len(df11_3a[df11_3a==3])
df12_3a=df12_3a["arousal"]
var1_12=len(df12_3a[df12_3a==1])
var2_12=len(df12_3a[df12_3a==2])
var3_12=len(df12_3a[df12_3a==3])
df13_3a=df13_3a["arousal"]
var1_13=len(df13_3a[df13_3a==1])
var2_13=len(df13_3a[df13_3a==2])
var3_13=len(df13_3a[df13_3a==3])
df14_3a=df14_3a["arousal"]
var1_14=len(df14_3a[df14_3a==1])
var2_14=len(df14_3a[df14_3a==2])
var3_14=len(df14_3a[df14_3a==3])
df15_3a=df15_3a["arousal"]
var1_15=len(df15_3a[df15_3a==1])
var2_15=len(df15_3a[df15_3a==2])
var3_15=len(df15_3a[df15_3a==3])
df16_3a=df16_3a["arousal"]
var1_16=len(df16_3a[df16_3a==1])
var2_16=len(df16_3a[df16_3a==2])
var3_16=len(df16_3a[df16_3a==3])
df17_3a=df17_3a["arousal"]
var1_17=len(df17_3a[df17_3a==1])
var2_17=len(df17_3a[df17_3a==2])
var3_17=len(df17_3a[df17_3a==3])
df18_3a=df18_3a["arousal"]
var1_18=len(df18_3a[df18_3a==1])
var2_18=len(df18_3a[df18_3a==2])
var3_18=len(df18_3a[df18_3a==3])
df19_3a=df19_3a["arousal"]
var1_19=len(df19_3a[df19_3a==1])
var2_19=len(df19_3a[df19_3a==2])
var3_19=len(df19_3a[df19_3a==3])
df20_3a=df20_3a["arousal"]
var1_20=len(df20_3a[df20_3a==1])
var2_20=len(df20_3a[df20_3a==2])
var3_20=len(df20_3a[df20_3a==3])
df21_3a=df21_3a["arousal"]
var1_21=len(df21_3a[df21_3a==1])
var2_21=len(df21_3a[df21_3a==2])
var3_21=len(df21_3a[df21_3a==3])
df22_3a=df22_3a["arousal"]
var1_22=len(df22_3a[df22_3a==1])
var2_22=len(df22_3a[df22_3a==2])
var3_22=len(df22_3a[df22_3a==3])
df23_3a=df23_3a["arousal"]
var1_23=len(df23_3a[df23_3a==1])
var2_23=len(df23_3a[df23_3a==2])
var3_23=len(df23_3a[df23_3a==3])
df24_3a=df24_3a["arousal"]
var1_24=len(df24_3a[df24_3a==1])
var2_24=len(df24_3a[df24_3a==2])
var3_24=len(df24_3a[df24_3a==3])
df25_3a=df25_3a["arousal"]
var1_25=len(df25_3a[df25_3a==1])
var2_25=len(df25_3a[df25_3a==2])
var3_25=len(df25_3a[df25_3a==3])
df26_3a=df26_3a["arousal"]
var1_26=len(df26_3a[df26_3a==1])
var2_26=len(df26_3a[df26_3a==2])
var3_26=len(df26_3a[df26_3a==3])
df27_3a=df27_3a["arousal"]
var1_27=len(df27_3a[df27_3a==1])
var2_27=len(df27_3a[df27_3a==2])
var3_27=len(df27_3a[df27_3a==3])
df28_3a=df28_3a["arousal"]
var1_28=len(df28_3a[df28_3a==1])
var2_28=len(df28_3a[df28_3a==2])
var3_28=len(df28_3a[df28_3a==3])
df29_3a=df29_3a["arousal"]
var1_29=len(df29_3a[df29_3a==1])
var2_29=len(df29_3a[df29_3a==2])
var3_29=len(df29_3a[df29_3a==3])
df30_3a=df30_3a["arousal"]
var1_30=len(df30_3a[df30_3a==1])
var2_30=len(df30_3a[df30_3a==2])
var3_30=len(df30_3a[df30_3a==3])
d = pd.DataFrame({'name': ["Subject 1","Subject 2","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 26","Subject 27","Subject 28","Subject 29","Subject 30"], '1': [var1_1,var1_2,var1_3,var1_4,var1_5,var1_6,var1_7,var1_8,var1_9,var1_10,var1_11,var1_12,var1_13,var1_14,var1_15,var1_16,var1_17,var1_18,var1_19,var1_20,var1_21,var1_22,var1_23,var1_24,var1_25,var1_26,var1_27,var1_28,var1_29,var1_30],'2': [var2_1,var2_2,var2_3,var2_4,var2_5,var2_6,var2_7,var2_8,var2_9,var2_10,var2_11,var2_12,var2_13,var2_14,var2_15,var2_16,var2_17,var2_18,var2_19,var2_20,var2_21,var2_22,var2_23,var2_24,var2_25,var2_26,var2_27,var2_28,var2_29,var2_30], '3':[var3_1,var3_2,var3_3,var3_4,var3_5,var3_6,var3_7,var3_8,var3_9,var3_10,var3_11,var3_12,var3_13,var3_14,var3_15,var3_16,var3_17,var3_18,var3_19,var3_20,var3_21,var3_22,var3_23,var3_24,var3_25,var3_26,var3_27,var3_28,var3_29,var3_30]})
d=d.reindex(columns=["name","3","2","1"])
d
# Out:
#           name     3     2    1
# 0    Subject 1  1243  1202   95
# 1    Subject 2   638  1799  103
# 2    Subject 3  1129  1163  248
# 3    Subject 4  1184  1248  108
# 4    Subject 5   625  1508  407
# 5    Subject 6   412  1929  199
# 6    Subject 7   395  2097   48
# 7    Subject 8  1035   951  554
# 8    Subject 9   387  2147    6
# 9   Subject 10   650  1877   13
# 10  Subject 11   425  1907  208
# 11  Subject 12   882  1535  123
# 12  Subject 13   540  1949   51
# 13  Subject 14   577  1963    0
# 14  Subject 15   513  2020    7
# 15  Subject 16   509  1794  237
# 16  Subject 17   533  1982   25
# 17  Subject 18   327  2213    0
# 18  Subject 19   523  2017    0
# 19  Subject 20   884  1548  108
# 20  Subject 21   385  1767  388
# 21  Subject 22   820  1617  103
# 22  Subject 23   476  1913  151
# 23  Subject 24   518  1622  400
# 24  Subject 25   778  1415  347
# 25  Subject 26   674  1673  193
# 26  Subject 27   486  1844  210
# 27  Subject 28   518  1916  106
# ...

# %%
d.plot(x="name",stacked = True,kind = 'barh', width=0.8, ylabel="")
plt.legend(fontsize=6,loc="lower left")
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.ylabel("")

df_total = d["1"] + d["2"]+ d["3"]
df_rel = d[d.columns[1:]].div(df_total, 0) * 100
  
for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(d.iloc[:, 1:].cumsum(1)[n], 
                                         d[n], df_rel[n])):
        plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'left', fontsize = 6,color="k")

# %% [markdown]
# 3 clases valence

# %%
df1_3v=df1_3v["valence"]
var1_1=len(df1_3v[df1_3v==1])
var2_1=len(df1_3v[df1_3v==2])
var3_1=len(df1_3v[df1_3v==3])
df2_3v=df2_3v["valence"]
var1_2=len(df2_3v[df2_3v==1])
var2_2=len(df2_3v[df2_3v==2])
var3_2=len(df2_3v[df2_3v==3])
df3_3v=df3_3v["valence"]
var1_3=len(df3_3v[df3_3v==1])
var2_3=len(df3_3v[df3_3v==2])
var3_3=len(df3_3v[df3_3v==3])
df4_3v=df4_3v["valence"]
var1_4=len(df4_3v[df4_3v==1])
var2_4=len(df4_3v[df4_3v==2])
var3_4=len(df4_3v[df4_3v==3])
df5_3v=df5_3v["valence"]
var1_5=len(df5_3v[df5_3v==1])
var2_5=len(df5_3v[df5_3v==2])
var3_5=len(df5_3v[df5_3v==3])
df6_3v=df6_3v["valence"]
var1_6=len(df6_3v[df6_3v==1])
var2_6=len(df6_3v[df6_3v==2])
var3_6=len(df6_3v[df6_3v==3])
df7_3v=df7_3v["valence"]
var1_7=len(df7_3v[df7_3v==1])
var2_7=len(df7_3v[df7_3v==2])
var3_7=len(df7_3v[df7_3v==3])
df8_3v=df8_3v["valence"]
var1_8=len(df8_3v[df8_3v==1])
var2_8=len(df8_3v[df8_3v==2])
var3_8=len(df8_3v[df8_3v==3])
df9_3v=df9_3v["valence"]
var1_9=len(df9_3v[df9_3v==1])
var2_9=len(df9_3v[df9_3v==2])
var3_9=len(df9_3v[df9_3v==3])
df10_3v=df10_3v["valence"]
var1_10=len(df10_3v[df10_3v==1])
var2_10=len(df10_3v[df10_3v==2])
var3_10=len(df10_3v[df10_3v==3])
df11_3v=df11_3v["valence"]
var1_11=len(df11_3v[df11_3v==1])
var2_11=len(df11_3v[df11_3v==2])
var3_11=len(df11_3v[df11_3v==3])
df12_3v=df12_3v["valence"]
var1_12=len(df12_3v[df12_3v==1])
var2_12=len(df12_3v[df12_3v==2])
var3_12=len(df12_3v[df12_3v==3])
df13_3v=df13_3v["valence"]
var1_13=len(df13_3v[df13_3v==1])
var2_13=len(df13_3v[df13_3v==2])
var3_13=len(df13_3v[df13_3v==3])
df14_3v=df14_3v["valence"]
var1_14=len(df14_3v[df14_3v==1])
var2_14=len(df14_3v[df14_3v==2])
var3_14=len(df14_3v[df14_3v==3])
df15_3v=df15_3v["valence"]
var1_15=len(df15_3v[df15_3v==1])
var2_15=len(df15_3v[df15_3v==2])
var3_15=len(df15_3v[df15_3v==3])
df16_3v=df16_3v["valence"]
var1_16=len(df16_3v[df16_3v==1])
var2_16=len(df16_3v[df16_3v==2])
var3_16=len(df16_3v[df16_3v==3])
df17_3v=df17_3v["valence"]
var1_17=len(df17_3v[df17_3v==1])
var2_17=len(df17_3v[df17_3v==2])
var3_17=len(df17_3v[df17_3v==3])
df18_3v=df18_3v["valence"]
var1_18=len(df18_3v[df18_3v==1])
var2_18=len(df18_3v[df18_3v==2])
var3_18=len(df18_3v[df18_3v==3])
df19_3v=df19_3v["valence"]
var1_19=len(df19_3v[df19_3v==1])
var2_19=len(df19_3v[df19_3v==2])
var3_19=len(df19_3v[df19_3v==3])
df20_3v=df20_3v["valence"]
var1_20=len(df20_3v[df20_3v==1])
var2_20=len(df20_3v[df20_3v==2])
var3_20=len(df20_3v[df20_3v==3])
df21_3v=df21_3v["valence"]
var1_21=len(df21_3v[df21_3v==1])
var2_21=len(df21_3v[df21_3v==2])
var3_21=len(df21_3v[df21_3v==3])
df22_3v=df22_3v["valence"]
var1_22=len(df22_3v[df22_3v==1])
var2_22=len(df22_3v[df22_3v==2])
var3_22=len(df22_3v[df22_3v==3])
df23_3v=df23_3v["valence"]
var1_23=len(df23_3v[df23_3v==1])
var2_23=len(df23_3v[df23_3v==2])
var3_23=len(df23_3v[df23_3v==3])
df24_3v=df24_3v["valence"]
var1_24=len(df24_3v[df24_3v==1])
var2_24=len(df24_3v[df24_3v==2])
var3_24=len(df24_3v[df24_3v==3])
df25_3v=df25_3v["valence"]
var1_25=len(df25_3v[df25_3v==1])
var2_25=len(df25_3v[df25_3v==2])
var3_25=len(df25_3v[df25_3v==3])
df26_3v=df26_3v["valence"]
var1_26=len(df26_3v[df26_3v==1])
var2_26=len(df26_3v[df26_3v==2])
var3_26=len(df26_3v[df26_3v==3])
df27_3v=df27_3v["valence"]
var1_27=len(df27_3v[df27_3v==1])
var2_27=len(df27_3v[df27_3v==2])
var3_27=len(df27_3v[df27_3v==3])
df28_3v=df28_3v["valence"]
var1_28=len(df28_3v[df28_3v==1])
var2_28=len(df28_3v[df28_3v==2])
var3_28=len(df28_3v[df28_3v==3])
df29_3v=df29_3v["valence"]
var1_29=len(df29_3v[df29_3v==1])
var2_29=len(df29_3v[df29_3v==2])
var3_29=len(df29_3v[df29_3v==3])
df30_3v=df30_3v["valence"]
var1_30=len(df30_3v[df30_3v==1])
var2_30=len(df30_3v[df30_3v==2])
var3_30=len(df30_3v[df30_3v==3])
d = pd.DataFrame({'name': ["Subject 1","Subject 2","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 26","Subject 27","Subject 28","Subject 29","Subject 30"], '1': [var1_1,var1_2,var1_3,var1_4,var1_5,var1_6,var1_7,var1_8,var1_9,var1_10,var1_11,var1_12,var1_13,var1_14,var1_15,var1_16,var1_17,var1_18,var1_19,var1_20,var1_21,var1_22,var1_23,var1_24,var1_25,var1_26,var1_27,var1_28,var1_29,var1_30],'2': [var2_1,var2_2,var2_3,var2_4,var2_5,var2_6,var2_7,var2_8,var2_9,var2_10,var2_11,var2_12,var2_13,var2_14,var2_15,var2_16,var2_17,var2_18,var2_19,var2_20,var2_21,var2_22,var2_23,var2_24,var2_25,var2_26,var2_27,var2_28,var2_29,var2_30], '3':[var3_1,var3_2,var3_3,var3_4,var3_5,var3_6,var3_7,var3_8,var3_9,var3_10,var3_11,var3_12,var3_13,var3_14,var3_15,var3_16,var3_17,var3_18,var3_19,var3_20,var3_21,var3_22,var3_23,var3_24,var3_25,var3_26,var3_27,var3_28,var3_29,var3_30]})
d=d.reindex(columns=["name","3","2","1"])
d
# Out:
#           name     3     2    1
# 0    Subject 1   938  1167  435
# 1    Subject 2   515  1594  431
# 2    Subject 3  1037  1066  437
# 3    Subject 4   724  1302  514
# 4    Subject 5   806  1278  456
# 5    Subject 6   865  1591   84
# 6    Subject 7   478  1980   82
# 7    Subject 8  1423   731  386
# 8    Subject 9   736  1512  292
# 9   Subject 10   989  1342  209
# 10  Subject 11   331  2169   40
# 11  Subject 12  1017  1322  201
# 12  Subject 13   743  1513  284
# 13  Subject 14   570  1970    0
# 14  Subject 15  1051  1279  210
# 15  Subject 16   942  1235  363
# 16  Subject 17   222  2311    7
# 17  Subject 18  1270  1270    0
# 18  Subject 19   510  1554  476
# 19  Subject 20   503  1710  327
# 20  Subject 21    58  2482    0
# 21  Subject 22   950  1242  348
# 22  Subject 23   490  1918  132
# 23  Subject 24   754  1556  230
# 24  Subject 25   590  1582  368
# 25  Subject 26   966  1366  208
# 26  Subject 27   874  1294  372
# 27  Subject 28   414  2126    0
# ...

# %%
d.plot(x="name",stacked = True,kind = 'barh', width=0.8, ylabel="")
plt.legend(fontsize=6,loc="lower left")
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.ylabel("")

df_total = d["1"] + d["2"]+ d["3"]
df_rel = d[d.columns[1:]].div(df_total, 0) * 100
  
for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(d.iloc[:, 1:].cumsum(1)[n], 
                                         d[n], df_rel[n])):
        plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'left', fontsize = 6,color="k")

# %% [markdown]
# 4 clases

# %%
df1_4=df1_4["valencearousal"]
var1_1=len(df1_4[df1_4==1])
var2_1=len(df1_4[df1_4==2])
var3_1=len(df1_4[df1_4==3])
var4_1=len(df1_4[df1_4==4])
df2_4=df2_4["valencearousal"]
var1_2=len(df2_4[df2_4==1])
var2_2=len(df2_4[df2_4==2])
var3_2=len(df2_4[df2_4==3])
var4_2=len(df2_4[df2_4==4])
df3_4=df3_4["valencearousal"]
var1_3=len(df3_4[df3_4==1])
var2_3=len(df3_4[df3_4==2])
var3_3=len(df3_4[df3_4==3])
var4_3=len(df3_4[df3_4==4])
df4_4=df4_4["valencearousal"]
var1_4=len(df4_4[df4_4==1])
var2_4=len(df4_4[df4_4==2])
var3_4=len(df4_4[df4_4==3])
var4_4=len(df4_4[df4_4==4])
df5_4=df5_4["valencearousal"]
var1_5=len(df5_4[df5_4==1])
var2_5=len(df5_4[df5_4==2])
var3_5=len(df5_4[df5_4==3])
var4_5=len(df5_4[df5_4==4])
df6_4=df6_4["valencearousal"]
var1_6=len(df6_4[df6_4==1])
var2_6=len(df6_4[df6_4==2])
var3_6=len(df6_4[df6_4==3])
var4_6=len(df6_4[df6_4==4])
df7_4=df7_4["valencearousal"]
var1_7=len(df7_4[df7_4==1])
var2_7=len(df7_4[df7_4==2])
var3_7=len(df7_4[df7_4==3])
var4_7=len(df7_4[df7_4==4])
df8_4=df8_4["valencearousal"]
var1_8=len(df8_4[df8_4==1])
var2_8=len(df8_4[df8_4==2])
var3_8=len(df8_4[df8_4==3])
var4_8=len(df8_4[df8_4==4])
df9_4=df9_4["valencearousal"]
var1_9=len(df9_4[df9_4==1])
var2_9=len(df9_4[df9_4==2])
var3_9=len(df9_4[df9_4==3])
var4_9=len(df9_4[df9_4==4])
df10_4=df10_4["valencearousal"]
var1_10=len(df10_4[df10_4==1])
var2_10=len(df10_4[df10_4==2])
var3_10=len(df10_4[df10_4==3])
var4_10=len(df10_4[df10_4==4])
df11_4=df11_4["valencearousal"]
var1_11=len(df11_4[df11_4==1])
var2_11=len(df11_4[df11_4==2])
var3_11=len(df11_4[df11_4==3])
var4_11=len(df11_4[df11_4==4])
df12_4=df12_4["valencearousal"]
var1_12=len(df12_4[df12_4==1])
var2_12=len(df12_4[df12_4==2])
var3_12=len(df12_4[df12_4==3])
var4_12=len(df12_4[df12_4==4])
df13_4=df13_4["valencearousal"]
var1_13=len(df13_4[df13_4==1])
var2_13=len(df13_4[df13_4==2])
var3_13=len(df13_4[df13_4==3])
var4_13=len(df13_4[df13_4==4])
df14_4=df14_4["valencearousal"]
var1_14=len(df14_4[df14_4==1])
var2_14=len(df14_4[df14_4==2])
var3_14=len(df14_4[df14_4==3])
var4_14=len(df14_4[df14_4==4])
df15_4=df15_4["valencearousal"]
var1_15=len(df15_4[df15_4==1])
var2_15=len(df15_4[df15_4==2])
var3_15=len(df15_4[df15_4==3])
var4_15=len(df15_4[df15_4==4])
df16_4=df16_4["valencearousal"]
var1_16=len(df16_4[df16_4==1])
var2_16=len(df16_4[df16_4==2])
var3_16=len(df16_4[df16_4==3])
var4_16=len(df16_4[df16_4==4])
df17_4=df17_4["valencearousal"]
var1_17=len(df17_4[df17_4==1])
var2_17=len(df17_4[df17_4==2])
var3_17=len(df17_4[df17_4==3])
var4_17=len(df17_4[df17_4==4])
df18_4=df18_4["valencearousal"]
var1_18=len(df18_4[df18_4==1])
var2_18=len(df18_4[df18_4==2])
var3_18=len(df18_4[df18_4==3])
var4_18=len(df18_4[df18_4==4])
df19_4=df19_4["valencearousal"]
var1_19=len(df19_4[df19_4==1])
var2_19=len(df19_4[df19_4==2])
var3_19=len(df19_4[df19_4==3])
var4_19=len(df19_4[df19_4==4])
df20_4=df20_4["valencearousal"]
var1_20=len(df20_4[df20_4==1])
var2_20=len(df20_4[df20_4==2])
var3_20=len(df20_4[df20_4==3])
var4_20=len(df20_4[df20_4==4])
df21_4=df21_4["valencearousal"]
var1_21=len(df21_4[df21_4==1])
var2_21=len(df21_4[df21_4==2])
var3_21=len(df21_4[df21_4==3])
var4_21=len(df21_4[df21_4==4])
df22_4=df22_4["valencearousal"]
var1_22=len(df22_4[df22_4==1])
var2_22=len(df22_4[df22_4==2])
var3_22=len(df22_4[df22_4==3])
var4_22=len(df22_4[df22_4==4])
df23_4=df23_4["valencearousal"]
var1_23=len(df23_4[df23_4==1])
var2_23=len(df23_4[df23_4==2])
var3_23=len(df23_4[df23_4==3])
var4_23=len(df23_4[df23_4==4])
df24_4=df24_4["valencearousal"]
var1_24=len(df24_4[df24_4==1])
var2_24=len(df24_4[df24_4==2])
var3_24=len(df24_4[df24_4==3])
var4_24=len(df24_4[df24_4==4])
df25_4=df25_4["valencearousal"]
var1_25=len(df25_4[df25_4==1])
var2_25=len(df25_4[df25_4==2])
var3_25=len(df25_4[df25_4==3])
var4_25=len(df25_4[df25_4==4])
df26_4=df26_4["valencearousal"]
var1_26=len(df26_4[df26_4==1])
var2_26=len(df26_4[df26_4==2])
var3_26=len(df26_4[df26_4==3])
var4_26=len(df26_4[df26_4==4])
df27_4=df27_4["valencearousal"]
var1_27=len(df27_4[df27_4==1])
var2_27=len(df27_4[df27_4==2])
var3_27=len(df27_4[df27_4==3])
var4_27=len(df27_4[df27_4==4])
df28_4=df28_4["valencearousal"]
var1_28=len(df28_4[df28_4==1])
var2_28=len(df28_4[df28_4==2])
var3_28=len(df28_4[df28_4==3])
var4_28=len(df28_4[df28_4==4])
df29_4=df29_4["valencearousal"]
var1_29=len(df29_4[df29_4==1])
var2_29=len(df29_4[df29_4==2])
var3_29=len(df29_4[df29_4==3])
var4_29=len(df29_4[df29_4==4])
df30_4=df30_4["valencearousal"]
var1_30=len(df30_4[df30_4==1])
var2_30=len(df30_4[df30_4==2])
var3_30=len(df30_4[df30_4==3])
var4_30=len(df30_4[df30_4==4])
d = pd.DataFrame({'name': ["Subject 1","Subject 2","Subject 3","Subject 4","Subject 5","Subject 6","Subject 7","Subject 8","Subject 9","Subject 10","Subject 11","Subject 12","Subject 13","Subject 14","Subject 15","Subject 16","Subject 17","Subject 18","Subject 19","Subject 20","Subject 21","Subject 22","Subject 23","Subject 24","Subject 25","Subject 26","Subject 27","Subject 28","Subject 29","Subject 30"], '1': [var1_1,var1_2,var1_3,var1_4,var1_5,var1_6,var1_7,var1_8,var1_9,var1_10,var1_11,var1_12,var1_13,var1_14,var1_15,var1_16,var1_17,var1_18,var1_19,var1_20,var1_21,var1_22,var1_23,var1_24,var1_25,var1_26,var1_27,var1_28,var1_29,var1_30],'2': [var2_1,var2_2,var2_3,var2_4,var2_5,var2_6,var2_7,var2_8,var2_9,var2_10,var2_11,var2_12,var2_13,var2_14,var2_15,var2_16,var2_17,var2_18,var2_19,var2_20,var2_21,var2_22,var2_23,var2_24,var2_25,var2_26,var2_27,var2_28,var2_29,var2_30], '3':[var3_1,var3_2,var3_3,var3_4,var3_5,var3_6,var3_7,var3_8,var3_9,var3_10,var3_11,var3_12,var3_13,var3_14,var3_15,var3_16,var3_17,var3_18,var3_19,var3_20,var3_21,var3_22,var3_23,var3_24,var3_25,var3_26,var3_27,var3_28,var3_29,var3_30], '4':[var4_1,var4_2,var4_3,var4_4,var4_5,var4_6,var4_7,var4_8,var4_9,var4_10,var4_11,var4_12,var4_13,var4_14,var4_15,var4_16,var4_17,var4_18,var4_19,var4_20,var4_21,var4_22,var4_23,var4_24,var4_25,var4_26,var4_27,var4_28,var4_29,var4_30]})
d=d.reindex(columns=["name","4","3","2","1"])
d
# Out:
#           name     4     3     2     1
# 0    Subject 1   895   490  1006   149
# 1    Subject 2   210   969   796   565
# 2    Subject 3   644   804   695   397
# 3    Subject 4  1038   339   770   393
# 4    Subject 5   560   968   667   345
# 5    Subject 6   801   508   388   843
# 6    Subject 7   758   755   532   495
# 7    Subject 8   847   847   662   184
# 8    Subject 9   196  1550   596   198
# 9   Subject 10   637   692   748   463
# 10  Subject 11   534  1006   520   480
# 11  Subject 12  1015   532   541   452
# 12  Subject 13   497   597   959   487
# 13  Subject 14   857   794   345   544
# 14  Subject 15  1181   540   395   424
# 15  Subject 16   414   625   472  1029
# 16  Subject 17   378   685   662   815
# 17  Subject 18  1365   788   153   234
# 18  Subject 19   495   312   908   825
# 19  Subject 20   940   727   676   197
# 20  Subject 21   313   277   961   989
# 21  Subject 22   886   353   760   541
# 22  Subject 23   204   851   486   999
# ...

# %%
d.plot(x="name",stacked = True,kind = 'barh', width=0.8, ylabel="")
plt.legend(fontsize=6,loc="upper left")
plt.yticks(fontsize=8)
plt.xticks(fontsize=8)
plt.ylabel("")

df_total = d["1"] + d["2"]+ d["3"]+ d["4"]
df_rel = d[d.columns[1:]].div(df_total, 0) * 100
  
for n in df_rel:
    for i, (cs, ab, pc) in enumerate(zip(d.iloc[:, 1:].cumsum(1)[n], 
                                         d[n], df_rel[n])):
        plt.text(cs - ab / 2, i, str(np.round(pc, 1)) + '%', 
                 va = 'center', ha = 'center', fontsize = 6,color="k")
